# %% [markdown]
# # ![](https://ga-dash.s3.amazonaws.com/production/assets/logo-9f88ae6c9c3871690e33280fcf557f33.png) SEC Pandas Lab
#
# Group review of Pandas Day One!
#
# ---

# %% [markdown]
# In this lab, we will use actual SEC daily trade data from the first week of December 2018.

# %%
import pandas as pd

import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# #### Using `pd.read_csv`, read in `'sec_dec_2018_w1.csv'` and store it as `sec_df`

# %%
sec_df = pd.read_csv('./datasets/sec_dec_2018_w1.csv')

# %% [markdown]
# #### Using `DataFrame.head`, look at the first five rows.

# %%
sec_df.head(10)
# Out:
#    Unnamed: 0      Date Security Ticker Exchange  McapRank  TurnRank  \
# 0           0  20181203    Stock      A     Amex      10.0       8.0
# 1           1  20181203    Stock      A     Arca      10.0       8.0
# 2           2  20181203    Stock      A   Bats-Y      10.0       8.0
# 3           3  20181203    Stock      A   Bats-Z      10.0       8.0
# 4           4  20181203    Stock      A   Boston      10.0       8.0
# 5           5  20181203    Stock      A      CHX      10.0       8.0
# 6           6  20181203    Stock      A   Edge-A      10.0       8.0
# 7           7  20181203    Stock      A   Edge-X      10.0       8.0
# 8           8  20181203    Stock      A      IEX      10.0       8.0
# 9           9  20181203    Stock      A      NSX      10.0       8.0
#
#    VolatilityRank  PriceRank  Cancels  ...  OrderVol('000)  TradeVol('000)  \
# 0             1.0        9.0    252.0  ...          28.028           5.764
# 1             1.0        9.0  17282.0  ...        1806.592         147.957
# 2             1.0        9.0  23948.0  ...        2577.323          95.522
# 3             1.0        9.0  86042.0  ...        9702.373         347.176
# 4             1.0        9.0   1910.0  ...         318.960          70.233
# 5             1.0        9.0    288.0  ...         157.277           0.175
# 6             1.0        9.0  15599.0  ...        1569.871         117.414
# 7             1.0        9.0  43290.0  ...        7942.280         132.137
# 8             1.0        9.0      0.0  ...             NaN         100.490
# 9             1.0        9.0    871.0  ...         137.178          38.734
#
#    LitVol('000)  OddLotVol('000)  HiddenVol('000)  TradeVolForHidden('000)  \
# 0         5.664            0.564            0.100                    5.764
# 1       126.345           23.460           21.612                  147.957
# 2        89.518           14.341            6.004                   95.522
# 3       318.967           53.460           28.209                  347.176
# 4        50.389           10.955           19.844                   70.233
# 5         0.175            0.175              NaN                      NaN
# 6       109.380           19.041            8.034                  117.414
# 7       123.106           16.936            9.031                  132.137
# 8           NaN            7.954              NaN                      NaN
# 9        36.434            8.544            2.300                   38.734
#
#    Date_str  Date_str2   Date_time  Weekday
# 0  20181203   20181203  2018-12-03   Monday
# 1  20181203   20181203  2018-12-03   Monday
# 2  20181203   20181203  2018-12-03   Monday
# 3  20181203   20181203  2018-12-03   Monday
# 4  20181203   20181203  2018-12-03   Monday
# 5  20181203   20181203  2018-12-03   Monday
# 6  20181203   20181203  2018-12-03   Monday
# 7  20181203   20181203  2018-12-03   Monday
# 8  20181203   20181203  2018-12-03   Monday
# 9  20181203   20181203  2018-12-03   Monday
#
# [10 rows x 25 columns]

# %% [markdown]
# #### Using DataFrame.sample, look at five randomly sampled rows.

# %%
sec_df.sample(5)
# Out:
#         Unnamed: 0      Date Security Ticker Exchange  McapRank  TurnRank  \
# 179072      179072  20181206      ETF   IBMN      NSX       1.0       4.0
# 70264        70264  20181204    Stock   CBAT      NSX       1.0       3.0
# 65610        65610  20181204    Stock   ANAB     Amex       7.0       8.0
# 87023        87023  20181204    Stock   LTHM   Edge-A       8.0       7.0
# 249385      249385  20181207      ETF   RUSS      NSX       2.0       4.0
#
#         VolatilityRank  PriceRank  Cancels  ...  OrderVol('000)  \
# 179072             1.0        2.0     19.0  ...           2.000
# 70264              1.0        1.0      2.0  ...           0.200
# 65610              8.0        9.0    172.0  ...          18.606
# 87023              9.0        5.0   1249.0  ...         134.680
# 249385             4.0        1.0   6580.0  ...         658.960
#
#         TradeVol('000)  LitVol('000)  OddLotVol('000)  HiddenVol('000)  \
# 179072           0.100         0.100            0.000            0.000
# 70264            0.000         0.000            0.000            0.000
# 65610            1.488         1.388            0.188            0.100
# 87023           21.500         6.172            0.989           15.328
# 249385           1.659         1.359            0.559            0.300
#
#         TradeVolForHidden('000)  Date_str  Date_str2   Date_time   Weekday
# 179072                    0.100  20181206   20181206  2018-12-06  Thursday
# 70264                     0.000  20181204   20181204  2018-12-04   Tuesday
# 65610                     1.488  20181204   20181204  2018-12-04   Tuesday
# 87023                    21.500  20181204   20181204  2018-12-04   Tuesday
# 249385                    1.659  20181207   20181207  2018-12-07    Friday
#
# [5 rows x 25 columns]

# %% [markdown]
# #### It is difficult to see all of the columns. Using the `columns` attribute, display all of the column names.

# %%
sec_df.columns
# Out:
# Index(['Unnamed: 0', 'Date', 'Security', 'Ticker', 'Exchange', 'McapRank',
#        'TurnRank', 'VolatilityRank', 'PriceRank', 'Cancels', 'Trades',
#        'LitTrades', 'OddLots', 'Hidden', 'TradesForHidden', 'OrderVol('000)',
#        'TradeVol('000)', 'LitVol('000)', 'OddLotVol('000)', 'HiddenVol('000)',
#        'TradeVolForHidden('000)', 'Date_str', 'Date_str2', 'Date_time',
#        'Weekday'],
#       dtype='object')

# %% [markdown]
# #### We should drop 'Unnamed: 0' from the columns. Run the following code once to drop it. Verify manually the column no longer exists.

# %%
sec_df = sec_df.drop(columns=['Unnamed: 0'])

sec_df.columns
# Out:
# Index(['Date', 'Security', 'Ticker', 'Exchange', 'McapRank', 'TurnRank',
#        'VolatilityRank', 'PriceRank', 'Cancels', 'Trades', 'LitTrades',
#        'OddLots', 'Hidden', 'TradesForHidden', 'OrderVol('000)',
#        'TradeVol('000)', 'LitVol('000)', 'OddLotVol('000)', 'HiddenVol('000)',
#        'TradeVolForHidden('000)', 'Date_str', 'Date_str2', 'Date_time',
#        'Weekday'],
#       dtype='object')

# %% [markdown]
# #### Many of these column names could be cleaned up! Run the following code once to make the column names more readable. Verify manually they are easier to read.

# %%
sec_df = sec_df.rename(columns={
    "OrderVol('000)": "OrderVol",
    "TradeVol('000)": "TradeVol",
    "LitVol('000)": "LitVol",
    "OddLotVol('000)": "OddLotVol",
    "HiddenVol('000)": "HiddenVol",
    "TradeVolForHidden('000)": "TradeVolForHidden"})

sec_df.columns
# Out:
# Index(['Date', 'Security', 'Ticker', 'Exchange', 'McapRank', 'TurnRank',
#        'VolatilityRank', 'PriceRank', 'Cancels', 'Trades', 'LitTrades',
#        'OddLots', 'Hidden', 'TradesForHidden', 'OrderVol', 'TradeVol',
#        'LitVol', 'OddLotVol', 'HiddenVol', 'TradeVolForHidden', 'Date_str',
#        'Date_str2', 'Date_time', 'Weekday'],
#       dtype='object')

# %% [markdown]
# #### Let's use `DataFrame.info` to get an overview of the data. How many rows do we have? How many columns?

# %%
sec_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 254563 entries, 0 to 254562
# Data columns (total 24 columns):
#  #   Column             Non-Null Count   Dtype
# ---  ------             --------------   -----
#  0   Date               254563 non-null  int64
#  1   Security           254563 non-null  object
#  2   Ticker             254563 non-null  object
#  3   Exchange           254563 non-null  object
#  4   McapRank           254560 non-null  float64
#  5   TurnRank           254560 non-null  float64
#  6   VolatilityRank     254528 non-null  float64
#  7   PriceRank          254560 non-null  float64
#  8   Cancels            254563 non-null  float64
#  9   Trades             249304 non-null  float64
#  10  LitTrades          232086 non-null  float64
#  11  OddLots            249304 non-null  float64
#  12  Hidden             221188 non-null  float64
#  13  TradesForHidden    221188 non-null  float64
#  14  OrderVol           237345 non-null  float64
#  15  TradeVol           249304 non-null  float64
#  16  LitVol             232086 non-null  float64
#  17  OddLotVol          249304 non-null  float64
#  18  HiddenVol          221188 non-null  float64
#  19  TradeVolForHidden  221188 non-null  float64
#  20  Date_str           254563 non-null  int64
#  21  Date_str2          254563 non-null  int64
#  22  Date_time          254563 non-null  object
#  23  Weekday            254563 non-null  object
# dtypes: float64(16), int64(3), object(5)
# memory usage: 46.6+ MB

# %% [markdown]
# #### It is difficult to see how many null values we have per column. Try using `DataFrame.isnull().sum()` to display the number of nulls per column.

# %%
sec_df.isnull().sum()
# Out:
# Date                     0
# Security                 0
# Ticker                   0
# Exchange                 0
# McapRank                 3
# TurnRank                 3
# VolatilityRank          35
# PriceRank                3
# Cancels                  0
# Trades                5259
# LitTrades            22477
# OddLots               5259
# Hidden               33375
# TradesForHidden      33375
# OrderVol             17218
# TradeVol              5259
# LitVol               22477
# OddLotVol             5259
# HiddenVol            33375
# TradeVolForHidden    33375
# Date_str                 0
# Date_str2                0
# Date_time                0
# Weekday                  0
# dtype: int64

# %% [markdown]
# #### Let's make sure the numeric columns make sense. Use `DataFrame.describe` and scan the columns for any strange values. Does this help you make sense of the `Rank` columns?

# %%
sec_df.describe()
# Out:
#                Date       McapRank       TurnRank  VolatilityRank  \
# count  2.545630e+05  254560.000000  254560.000000   254528.000000
# mean   2.018121e+07       4.779942       4.775047        4.554615
# std    1.580150e+00       2.806829       2.790079        2.768868
# min    2.018120e+07       1.000000       1.000000        1.000000
# 25%    2.018120e+07       2.000000       2.000000        2.000000
# 50%    2.018121e+07       4.000000       4.000000        4.000000
# 75%    2.018121e+07       7.000000       7.000000        7.000000
# max    2.018121e+07      10.000000      10.000000       10.000000
#
#            PriceRank       Cancels         Trades      LitTrades  \
# count  254560.000000  2.545630e+05  249304.000000  232086.000000
# mean        4.670439  1.466110e+04     498.695954     439.098153
# std         2.842624  5.588649e+04    2386.031292    2220.094593
# min         1.000000  0.000000e+00       0.000000       0.000000
# 25%         2.000000  7.000000e+01       2.000000       1.000000
# 50%         4.000000  1.009000e+03      30.000000      18.000000
# 75%         7.000000  7.433000e+03     228.000000     172.000000
# max        10.000000  2.976401e+06  275459.000000  260374.000000
#
#              OddLots         Hidden  TradesForHidden      OrderVol  \
# count  249304.000000  221188.000000    221188.000000  2.373450e+05
# mean      158.334567      76.882412       537.143932  6.125240e+03
# std       760.457385     338.494375      2519.680467  4.142193e+04
# min         0.000000      -1.000000         0.000000  0.000000e+00
# 25%         0.000000       0.000000         2.000000  1.813200e+01
# 50%         9.000000       6.000000        34.000000  2.102040e+02
# 75%        76.000000      44.000000       246.000000  1.555780e+03
# max     68899.000000   40705.000000    275459.000000  4.524973e+06
#
#             TradeVol         LitVol      OddLotVol      HiddenVol  \
# count  249304.000000  232086.000000  249304.000000  221188.000000
# mean       64.667887      57.317608       5.221436       9.286660
# std       428.077728     397.975153      23.539697      52.260954
# min         0.000000       0.000000       0.000000      -0.100000
# 25%         0.102000       0.010000       0.000000       0.000000
# 50%         2.843000       1.700000       0.280000       0.534500
# 75%        21.753000      15.935750       2.476000       4.261000
# max     40774.537000   36210.688000    1913.010000    4563.849000
#
#        TradeVolForHidden      Date_str     Date_str2
# count      221188.000000  2.545630e+05  2.545630e+05
# mean           69.208412  2.018121e+07  2.018121e+07
# std           452.039555  1.580150e+00  1.580150e+00
# min             0.000000  2.018120e+07  2.018120e+07
# 25%             0.169000  2.018120e+07  2.018120e+07
# 50%             3.219000  2.018121e+07  2.018121e+07
# 75%            23.102000  2.018121e+07  2.018121e+07
# max         40774.537000  2.018121e+07  2.018121e+07

# %% [markdown]
# #### Let's verify the data is actually from the first week of December 2018! Since it is difficult to read in the summary above, print `Series.min` and `Series.max` to find the smallest and largest dates in the `'Date'` column.

# %%
print(sec_df.Date.min())
print(sec_df.Date.max())
# Out:
# 20181203
# 20181207

# %% [markdown]
# #### The columns `'Date'`, `'Date_str'`, `'Date_str2'`, and `'Date_time'` have similar names. Try indexing `sec_df` by them to display them side-by-side. Do they seem to have different contents?

# %%
sec_df[['Date', 'Date_str', 'Date_str2', 'Date_time']].head(5)
# Out:
#        Date  Date_str  Date_str2   Date_time
# 0  20181203  20181203   20181203  2018-12-03
# 1  20181203  20181203   20181203  2018-12-03
# 2  20181203  20181203   20181203  2018-12-03
# 3  20181203  20181203   20181203  2018-12-03
# 4  20181203  20181203   20181203  2018-12-03

# %% [markdown]
# #### Let's see how many entries we have per stock exchange.
#
# 1. First, index by `'Exchange'` to get a `Series` of the exchange column.

# %%
sec_df['Exchange']
# Out:
# 0           Amex
# 1           Arca
# 2         Bats-Y
# 3         Bats-Z
# 4         Boston
#            ...
# 254558    Edge-X
# 254559       NSX
# 254560      NYSE
# 254561    Nasdaq
# 254562      Phlx
# Name: Exchange, Length: 254563, dtype: object

# %% [markdown]
# 2. Now, add on to the last answer. Use `Series.value_counts()` on the `'Exchange'` column to see how many rows we have per exchange.

# %%
sec_df['Exchange'].value_counts()
# Out:
# Nasdaq    22674
# Bats-Z    22568
# Arca      22559
# Edge-X    22294
# Edge-A    22159
# Bats-Y    22128
# Boston    20584
# NSX       18834
# Phlx      18749
# NYSE      17940
# IEX       17218
# Amex      15958
# CHX       10898
# Name: Exchange, dtype: int64

# %% [markdown]
# 3. Again, we'll add on to the last answer. Notice the output of `Series.value_counts` is a `Series`! Use `Series.plot(kind='bar')` to view the value counts as a bar plot.

# %%
sec_df['Exchange'].value_counts().plot.bar()
# Out:
# <AxesSubplot:>

# %% [markdown]
# #### Using the same procedure, can you show the `value_counts` of each type of security?

# %%
sec_df['Security'].value_counts().plot.bar()
# Out:
# <AxesSubplot:>

# %% [markdown]
# #### Let's understand the `'PriceRank'` column better. Plot a histogram using `Series.hist` to see how the `'PriceRank'` values are distributed. Can you describe what this graph means? What might be good labels for the x and y axes? (Bonus: Do you know why it is distributed how it is?)

# %%
sec_df['PriceRank'].hist()
# Out:
# <AxesSubplot:>

# %% [markdown]
# #### Let's look at Apple (AAPL) stock.
#
# 1. First, filter the rows only to those where the column `'Ticker'` is `'AAPL'`. Save this as `aapl_df`.

# %%
aapl_df = sec_df[sec_df['Ticker'] == 'AAPL']

aapl_df.head()
# Out:
#          Date Security Ticker Exchange  McapRank  TurnRank  VolatilityRank  \
# 120  20181203    Stock   AAPL     Amex      10.0       7.0             2.0
# 121  20181203    Stock   AAPL     Arca      10.0       7.0             2.0
# 122  20181203    Stock   AAPL   Bats-Y      10.0       7.0             2.0
# 123  20181203    Stock   AAPL   Bats-Z      10.0       7.0             2.0
# 124  20181203    Stock   AAPL   Boston      10.0       7.0             2.0
#
#      PriceRank   Cancels   Trades  ...   OrderVol  TradeVol    LitVol  \
# 120       10.0     631.0    273.0  ...    129.717    23.202    15.502
# 121       10.0  312364.0  27526.0  ...  87739.713  3049.431  2633.764
# 122       10.0   75598.0   4862.0  ...   6161.888   377.358   232.941
# 123       10.0  539228.0  23684.0  ...  59485.173  2000.638  1757.547
# 124       10.0   55080.0   4894.0  ...   3907.576   430.685   347.511
#
#      OddLotVol  HiddenVol  TradeVolForHidden  Date_str  Date_str2   Date_time  \
# 120      2.928      7.700             23.202  20181203   20181203  2018-12-03
# 121    396.008    415.667           3049.431  20181203   20181203  2018-12-03
# 122     71.569    144.417            377.358  20181203   20181203  2018-12-03
# 123    282.486    243.091           2000.638  20181203   20181203  2018-12-03
# 124     55.223     83.174            430.685  20181203   20181203  2018-12-03
#
#      Weekday
# 120   Monday
# 121   Monday
# 122   Monday
# 123   Monday
# 124   Monday
#
# [5 rows x 24 columns]

# %% [markdown]
# 2. Which exchange had the most trades of AAPL?

# %%
aapl_df.Exchange.value_counts()
# Out:
# Bats-Z    4
# IEX       4
# NYSE      4
# Boston    4
# Arca      4
# Amex      4
# Bats-Y    4
# Phlx      4
# NSX       4
# Edge-X    4
# Nasdaq    4
# Edge-A    4
# CHX       4
# Name: Exchange, dtype: int64

# %% [markdown]
# #### Let's only look at Nasdaq.
#
# 1. Filter the rows to only those where the `'Exchange'` column is `'Nasdaq'`. Save this as `nasdaq_df`.

# %%
nasdaq_df = sec_df[sec_df.Exchange == 'Nasdaq']

nasdaq_df.head()
# Out:
#         Date Security Ticker Exchange  McapRank  TurnRank  VolatilityRank  \
# 11  20181203    Stock      A   Nasdaq      10.0       8.0             1.0
# 24  20181203    Stock     AA   Nasdaq       9.0       9.0             5.0
# 37  20181203    Stock    AAC   Nasdaq       2.0       9.0             9.0
# 50  20181203    Stock    AAL   Nasdaq      10.0       9.0             5.0
# 59  20181203    Stock   AAMC   Nasdaq       2.0       2.0            10.0
#
#     PriceRank   Cancels   Trades  ...   OrderVol  TradeVol    LitVol  \
# 11        9.0   47834.0   9387.0  ...   5486.483   768.270   648.293
# 24        7.0   62298.0   3254.0  ...   6741.526   293.737   266.018
# 37        2.0    2948.0    293.0  ...    736.605    36.508    31.376
# 50        7.0  240539.0  11681.0  ...  59414.940  1263.542  1181.346
# 59        8.0    1219.0      3.0  ...    378.426     0.041     0.004
#
#     OddLotVol  HiddenVol  TradeVolForHidden  Date_str  Date_str2   Date_time  \
# 11    141.274    119.977            768.270  20181203   20181203  2018-12-03
# 24     36.650     27.719            293.737  20181203   20181203  2018-12-03
# 37      1.563      5.132             36.508  20181203   20181203  2018-12-03
# 50    144.039     82.196           1263.542  20181203   20181203  2018-12-03
# 59      0.041      0.037              0.041  20181203   20181203  2018-12-03
#
#     Weekday
# 11   Monday
# 24   Monday
# 37   Monday
# 50   Monday
# 59   Monday
#
# [5 rows x 24 columns]

# %% [markdown]
# 2. Which ticker and day had the most trades on Nasdaq in this data?

# %%
nasdaq_df.sort_values('Trades', ascending = False)
# Out:
#             Date Security Ticker Exchange  McapRank  TurnRank  VolatilityRank  \
# 187325  20181206      ETF    SPY   Nasdaq       4.0       4.0             3.0
# 123509  20181204      ETF    SPY   Nasdaq       4.0       4.0             4.0
# 251083  20181207      ETF    SPY   Nasdaq       4.0       4.0             4.0
# 59858   20181203      ETF    SPY   Nasdaq       4.0       4.0             3.0
# 152958  20181206    Stock   MSFT   Nasdaq      10.0       5.0             3.0
# ...          ...      ...    ...      ...       ...       ...             ...
# 57585   20181203      ETF   RBUS   Nasdaq       3.0       1.0             2.0
# 57582   20181203      ETF   RBIN   Nasdaq       3.0       1.0             2.0
# 57579   20181203      ETF   RAVI   Nasdaq       3.0       1.0             1.0
# 57571   20181203      ETF   RALS   Nasdaq       1.0       3.0             4.0
# 121156  20181204      ETF   QWLD   Nasdaq       2.0       1.0             3.0
#
#         PriceRank    Cancels    Trades  ...    OrderVol   TradeVol     LitVol  \
# 187325        4.0  2976401.0  275459.0  ...  532032.764  34354.661  31267.221
# 123509        4.0  2649800.0  259345.0  ...  467901.631  34798.613  31361.620
# 251083        4.0  2417441.0  236376.0  ...  437867.789  28404.372  25495.543
# 59858         4.0  1729621.0  139728.0  ...  334045.140  19288.734  17797.630
# 152958       10.0  1214196.0  111235.0  ...  155515.238  10835.577   9832.595
# ...           ...        ...       ...  ...         ...        ...        ...
# 57585         2.0       11.0       0.0  ...       0.700      0.000      0.000
# 57582         2.0       14.0       0.0  ...       0.600      0.000      0.000
# 57579         4.0       48.0       0.0  ...      12.200      0.000      0.000
# 57571         3.0      369.0       0.0  ...      36.049      0.000      0.000
# 121156        4.0     3036.0       0.0  ...     518.400      0.000      0.000
#
#         OddLotVol  HiddenVol  TradeVolForHidden  Date_str  Date_str2  \
# 187325   1913.010   3087.440          34354.661  20181206   20181206
# 123509   1613.420   3436.993          34798.613  20181204   20181204
# 251083   1887.702   2908.829          28404.372  20181207   20181207
# 59858     878.177   1491.104          19288.734  20181203   20181203
# 152958   1136.355   1002.982          10835.577  20181206   20181206
# ...           ...        ...                ...       ...        ...
# 57585       0.000      0.000              0.000  20181203   20181203
# 57582       0.000      0.000              0.000  20181203   20181203
# 57579       0.000      0.000              0.000  20181203   20181203
# 57571       0.000      0.000              0.000  20181203   20181203
# 121156      0.000      0.000              0.000  20181204   20181204
#
#          Date_time   Weekday
# 187325  2018-12-06  Thursday
# 123509  2018-12-04   Tuesday
# 251083  2018-12-07    Friday
# 59858   2018-12-03    Monday
# 152958  2018-12-06  Thursday
# ...            ...       ...
# 57585   2018-12-03    Monday
# 57582   2018-12-03    Monday
# 57579   2018-12-03    Monday
# 57571   2018-12-03    Monday
# 121156  2018-12-04   Tuesday
#
# [22674 rows x 24 columns]

# %% [markdown]
# #### Finally, let's save a report of our AAPL data as an Excel file. This saves it in the current directory. Try opening the report in Excel!

# %%
aapl_df.to_excel('aapl_report.xls')

# %%
# Displays the Present Working Directory where the report is
# %pwd
# Out:
# 'C:\\Users\\614318\\TEDS\\203-pandas'
