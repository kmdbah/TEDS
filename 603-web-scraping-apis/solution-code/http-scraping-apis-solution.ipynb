# %% [markdown]
# <img src="http://imgur.com/1ZcRyrc.png" style="float: left; margin: 20px; height: 55px">
#
# # Data Science on the Net!
# ---
#
# ## Learning Objectives
# * **Explain** how HTTP works
# * **Make** HTTP requests from Python
# * **Read** API documentation and get the data
# * **Scrape** a website using BeautifulSoup
#
#
#
# ![](http://i.imgur.com/zjwHc.jpg)

# %% [markdown]
# ## Part 1: HTML = The Language of the Web
# HTML is a language that describes the "nouns" of the internet. HTML objects come in _tags_ that look like this:
#
# ```html
# <tag>Contents of the tag</tag>
# ```
#
# Let's go to a website (any website!) and open the object viewer by pressing **Ctrl-Shift-i**.
# Maybe:
# * www.washingtonpost.com
# * www.example.com
# * www.realpython.com
#
# HTML tags can have **classes** and **ids**, too.
# * **Classes** are non-unique descriptors that you can use to identify various HTML tags by a joining quality. For example, you might define a "foreground" class. You can use CSS to then color all "foreground" class objects blue.
# * **ids** are _unique_ descriptors. They work the same as classes, except there can only be one tag per id.
#
# For example:
# ```html
# <p class="speech" id="gettysburg">Four score and seven years ago our fathers brought forth on this continent, a new nation, conceived in Liberty, and dedicated to the proposition that all men are created equal.</p>
# ```

# %% [markdown]
# ## Part 2: The HTTP Protocol
# HTTP is the **hypertext transfer protocol**. It's just a system of rules for throwing data around the internet.
#
# > Aside: There are other protocols you might have heard of. For example: FTP (file transfer protocol), SFTP (Secure FTP), and IP (internet protocol).
#
# You can interact using the HTTP via different kinds of **requests**. There are several of them, but two are used most widely: **GET** and **POST**.
# * The GET request is for getting data.
#     - What Tweets are in my news feed?
# * The POST request is for telling a server what data _you_ have, often times causing the server to act upon it.
#     - Post this Tweet espousing my controversial political opinions!
#
# HTTP requests also have **response codes (response statuses)**. You've probably heard of 404 (page not found). But there are many more: 200 (everything good), 300 (redirection), 401 (unauthorized).
#
# Let's go to any of those previous websites and go to the "Network" tab of the object viewer. Refresh the page. Every line you see is a series of HTTP requests and their response codes.

# %% [markdown]
# ## Part 3: The `requests` Library & APIs
# The `requests` library is a library for submitting HTTP requests from Python. Despite its frequent use, it's not included in the Python standard library. You'll need to `pip install requests` yourself.
# ![](assets/pokeapi.png)

# %%
import requests

# %%
# Create url for API call.
base_url = 'https://pokeapi.co/api/v2/'
get_pokemon_endpoint = 'pokemon/'

# %%
# Make request
pokemon_req = requests.get(base_url + get_pokemon_endpoint + 'snorlax')

# %%
# Request response code
pokemon_req
# Out:
# <Response [200]>

# %%
# Text of request
pokemon_req.text[:500]
# Out:
# '{"abilities":[{"ability":{"name":"immunity","url":"https://pokeapi.co/api/v2/ability/17/"},"is_hidden":false,"slot":1},{"ability":{"name":"thick-fat","url":"https://pokeapi.co/api/v2/ability/47/"},"is_hidden":false,"slot":2},{"ability":{"name":"gluttony","url":"https://pokeapi.co/api/v2/ability/82/"},"is_hidden":true,"slot":3}],"base_experience":189,"forms":[{"name":"snorlax","url":"https://pokeapi.co/api/v2/pokemon-form/143/"}],"game_indices":[{"game_index":132,"version":{"name":"red","url":"ht'

# %%
# Bring in the JSON!
snorlax = pokemon_req.json()

# %%
# Since we've converted the JSON -> dict, we know how to work with this!
snorlax.keys()
# Out:
# dict_keys(['abilities', 'base_experience', 'forms', 'game_indices', 'height', 'held_items', 'id', 'is_default', 'location_area_encounters', 'moves', 'name', 'order', 'species', 'sprites', 'stats', 'types', 'weight'])

# %%
# Height, Weight
height = snorlax['height']
weight = snorlax['weight']

height, weight
# Out:
# (21, 4600)

# %%
# Sprites?
snorlax['sprites']['front_default']
# Out:
# 'https://raw.githubusercontent.com/PokeAPI/sprites/master/sprites/pokemon/143.png'

# %%
# What moves can squirtle learn?
pokemon_req = requests.get(base_url + get_pokemon_endpoint + 'squirtle')
squirtle = pokemon_req.json()

[move['move']['name'] for move in squirtle['moves']]
# Out:
# ['mega-punch',
#  'ice-punch',
#  'mega-kick',
#  'headbutt',
#  'tackle',
#  'body-slam',
#  'take-down',
#  'double-edge',
#  'tail-whip',
#  'bite',
#  'mist',
#  'water-gun',
#  'hydro-pump',
#  'surf',
#  'ice-beam',
#  'blizzard',
#  'bubble-beam',
#  'submission',
#  'counter',
#  'seismic-toss',
#  'strength',
#  'dig',
#  'toxic',
#  'confusion',
#  'rage',
#  'mimic',
#  'double-team',
#  'withdraw',
#  'defense-curl',
#  'haze',
#  'reflect',
#  'bide',
#  'waterfall',
#  'skull-bash',
#  'bubble',
#  'rest',
#  'substitute',
#  'snore',
#  'curse',
#  'flail',
#  'protect',
#  'mud-slap',
#  'foresight',
#  'icy-wind',
#  'endure',
#  'rollout',
#  'swagger',
#  'attract',
#  'sleep-talk',
#  'return',
#  'frustration',
#  'dynamic-punch',
#  'rapid-spin',
#  'iron-tail',
#  'hidden-power',
#  'rain-dance',
#  'mirror-coat',
#  'rock-smash',
#  'whirlpool',
#  'fake-out',
#  'hail',
#  'facade',
#  'focus-punch',
#  'brick-break',
#  'yawn',
#  'refresh',
#  'secret-power',
#  'dive',
#  'mud-sport',
#  'rock-tomb',
#  'water-spout',
#  'muddy-water',
#  'iron-defense',
#  'water-pulse',
#  'gyro-ball',
#  'brine',
#  'natural-gift',
#  'fling',
#  'aqua-ring',
#  'aura-sphere',
#  'aqua-tail',
#  'dragon-pulse',
#  'zen-headbutt',
#  'captivate',
#  'aqua-jet',
#  'round',
#  'scald',
#  'water-pledge',
#  'work-up',
#  'confide',
#  'power-up-punch']

# %%
# Whoa! Let's build a function to extract a pokemon's possible moves

def get_moves(pokemon_name):
    url = base_url + get_pokemon_endpoint + pokemon_name
    pokemon_req = requests.get(url)
    pokemon = pokemon_req.json()

    return [move['move']['name'] for move in pokemon['moves']]

# %%
get_moves('charmander')
# Out:
# ['mega-punch',
#  'fire-punch',
#  'thunder-punch',
#  'scratch',
#  'swords-dance',
#  'cut',
#  'mega-kick',
#  'headbutt',
#  'body-slam',
#  'take-down',
#  'double-edge',
#  'leer',
#  'bite',
#  'growl',
#  'ember',
#  'flamethrower',
#  'submission',
#  'counter',
#  'seismic-toss',
#  'strength',
#  'dragon-rage',
#  'fire-spin',
#  'dig',
#  'toxic',
#  'rage',
#  'mimic',
#  'double-team',
#  'smokescreen',
#  'defense-curl',
#  'reflect',
#  'bide',
#  'fire-blast',
#  'swift',
#  'skull-bash',
#  'rest',
#  'rock-slide',
#  'slash',
#  'substitute',
#  'snore',
#  'curse',
#  'protect',
#  'scary-face',
#  'belly-drum',
#  'mud-slap',
#  'outrage',
#  'endure',
#  'swagger',
#  'fury-cutter',
#  'attract',
#  'sleep-talk',
#  'return',
#  'frustration',
#  'dynamic-punch',
#  'dragon-breath',
#  'iron-tail',
#  'metal-claw',
#  'hidden-power',
#  'sunny-day',
#  'crunch',
#  'ancient-power',
#  'rock-smash',
#  'beat-up',
#  'heat-wave',
#  'will-o-wisp',
#  'facade',
#  'focus-punch',
#  'brick-break',
#  'secret-power',
#  'air-cutter',
#  'overheat',
#  'rock-tomb',
#  'aerial-ace',
#  'dragon-claw',
#  'dragon-dance',
#  'natural-gift',
#  'fling',
#  'flare-blitz',
#  'dragon-pulse',
#  'dragon-rush',
#  'shadow-claw',
#  'fire-fang',
#  'captivate',
#  'hone-claws',
#  'flame-burst',
#  'flame-charge',
#  'round',
#  'echoed-voice',
#  'incinerate',
#  'inferno',
#  'fire-pledge',
#  'work-up',
#  'confide',
#  'power-up-punch']

# %%
url = 'https://pokeapi.co/api/v2/pokemon'
params = {'offset':0, 'limit':300}

pokemon_urls= {}

while url:
    poke_req = requests.get(url, params=params)
    pokemon = poke_req.json()
    url = pokemon['next']
    
    for poke in pokemon['results']:
        pokemon_urls[poke['name']] = poke['url']
    print(url)
    
pokemon_urls
# Out:
# https://pokeapi.co/api/v2/pokemon?offset=300&limit=300
# https://pokeapi.co/api/v2/pokemon?offset=600&limit=300
# https://pokeapi.co/api/v2/pokemon?offset=900&limit=218
# None
# {'bulbasaur': 'https://pokeapi.co/api/v2/pokemon/1/',
#  'ivysaur': 'https://pokeapi.co/api/v2/pokemon/2/',
#  'venusaur': 'https://pokeapi.co/api/v2/pokemon/3/',
#  'charmander': 'https://pokeapi.co/api/v2/pokemon/4/',
#  'charmeleon': 'https://pokeapi.co/api/v2/pokemon/5/',
#  'charizard': 'https://pokeapi.co/api/v2/pokemon/6/',
#  'squirtle': 'https://pokeapi.co/api/v2/pokemon/7/',
#  'wartortle': 'https://pokeapi.co/api/v2/pokemon/8/',
#  'blastoise': 'https://pokeapi.co/api/v2/pokemon/9/',
#  'caterpie': 'https://pokeapi.co/api/v2/pokemon/10/',
#  'metapod': 'https://pokeapi.co/api/v2/pokemon/11/',
#  'butterfree': 'https://pokeapi.co/api/v2/pokemon/12/',
#  'weedle': 'https://pokeapi.co/api/v2/pokemon/13/',
#  'kakuna': 'https://pokeapi.co/api/v2/pokemon/14/',
#  'beedrill': 'https://pokeapi.co/api/v2/pokemon/15/',
#  'pidgey': 'https://pokeapi.co/api/v2/pokemon/16/',
#  'pidgeotto': 'https://pokeapi.co/api/v2/pokemon/17/',
#  'pidgeot': 'https://pokeapi.co/api/v2/pokemon/18/',
#  'rattata': 'https://pokeapi.co/api/v2/pokemon/19/',
#  'raticate': 'https://pokeapi.co/api/v2/pokemon/20/',
#  'spearow': 'https://pokeapi.co/api/v2/pokemon/21/',
#  'fearow': 'https://pokeapi.co/api/v2/pokemon/22/',
#  'ekans': 'https://pokeapi.co/api/v2/pokemon/23/',
#  'arbok': 'https://pokeapi.co/api/v2/pokemon/24/',
#  'pikachu': 'https://pokeapi.co/api/v2/pokemon/25/',
#  'raichu': 'https://pokeapi.co/api/v2/pokemon/26/',
#  'sandshrew': 'https://pokeapi.co/api/v2/pokemon/27/',
#  'sandslash': 'https://pokeapi.co/api/v2/pokemon/28/',
#  'nidoran-f': 'https://pokeapi.co/api/v2/pokemon/29/',
#  'nidorina': 'https://pokeapi.co/api/v2/pokemon/30/',
#  'nidoqueen': 'https://pokeapi.co/api/v2/pokemon/31/',
#  'nidoran-m': 'https://pokeapi.co/api/v2/pokemon/32/',
#  'nidorino': 'https://pokeapi.co/api/v2/pokemon/33/',
#  'nidoking': 'https://pokeapi.co/api/v2/pokemon/34/',
#  'clefairy': 'https://pokeapi.co/api/v2/pokemon/35/',
#  'clefable': 'https://pokeapi.co/api/v2/pokemon/36/',
#  'vulpix': 'https://pokeapi.co/api/v2/pokemon/37/',
#  'ninetales': 'https://pokeapi.co/api/v2/pokemon/38/',
#  'jigglypuff': 'https://pokeapi.co/api/v2/pokemon/39/',
#  'wigglytuff': 'https://pokeapi.co/api/v2/pokemon/40/',
#  'zubat': 'https://pokeapi.co/api/v2/pokemon/41/',
#  'golbat': 'https://pokeapi.co/api/v2/pokemon/42/',
#  'oddish': 'https://pokeapi.co/api/v2/pokemon/43/',
#  'gloom': 'https://pokeapi.co/api/v2/pokemon/44/',
#  'vileplume': 'https://pokeapi.co/api/v2/pokemon/45/',
#  'paras': 'https://pokeapi.co/api/v2/pokemon/46/',
#  'parasect': 'https://pokeapi.co/api/v2/pokemon/47/',
#  'venonat': 'https://pokeapi.co/api/v2/pokemon/48/',
#  'venomoth': 'https://pokeapi.co/api/v2/pokemon/49/',
#  'diglett': 'https://pokeapi.co/api/v2/pokemon/50/',
#  'dugtrio': 'https://pokeapi.co/api/v2/pokemon/51/',
#  'meowth': 'https://pokeapi.co/api/v2/pokemon/52/',
#  'persian': 'https://pokeapi.co/api/v2/pokemon/53/',
#  'psyduck': 'https://pokeapi.co/api/v2/pokemon/54/',
#  'golduck': 'https://pokeapi.co/api/v2/pokemon/55/',
#  'mankey': 'https://pokeapi.co/api/v2/pokemon/56/',
#  'primeape': 'https://pokeapi.co/api/v2/pokemon/57/',
#  'growlithe': 'https://pokeapi.co/api/v2/pokemon/58/',
#  'arcanine': 'https://pokeapi.co/api/v2/pokemon/59/',
#  'poliwag': 'https://pokeapi.co/api/v2/pokemon/60/',
#  'poliwhirl': 'https://pokeapi.co/api/v2/pokemon/61/',
#  'poliwrath': 'https://pokeapi.co/api/v2/pokemon/62/',
#  'abra': 'https://pokeapi.co/api/v2/pokemon/63/',
#  'kadabra': 'https://pokeapi.co/api/v2/pokemon/64/',
#  'alakazam': 'https://pokeapi.co/api/v2/pokemon/65/',
#  'machop': 'https://pokeapi.co/api/v2/pokemon/66/',
#  'machoke': 'https://pokeapi.co/api/v2/pokemon/67/',
#  'machamp': 'https://pokeapi.co/api/v2/pokemon/68/',
#  'bellsprout': 'https://pokeapi.co/api/v2/pokemon/69/',
#  'weepinbell': 'https://pokeapi.co/api/v2/pokemon/70/',
#  'victreebel': 'https://pokeapi.co/api/v2/pokemon/71/',
#  'tentacool': 'https://pokeapi.co/api/v2/pokemon/72/',
#  'tentacruel': 'https://pokeapi.co/api/v2/pokemon/73/',
#  'geodude': 'https://pokeapi.co/api/v2/pokemon/74/',
#  'graveler': 'https://pokeapi.co/api/v2/pokemon/75/',
#  'golem': 'https://pokeapi.co/api/v2/pokemon/76/',
#  'ponyta': 'https://pokeapi.co/api/v2/pokemon/77/',
#  'rapidash': 'https://pokeapi.co/api/v2/pokemon/78/',
#  'slowpoke': 'https://pokeapi.co/api/v2/pokemon/79/',
#  'slowbro': 'https://pokeapi.co/api/v2/pokemon/80/',
#  'magnemite': 'https://pokeapi.co/api/v2/pokemon/81/',
#  'magneton': 'https://pokeapi.co/api/v2/pokemon/82/',
#  'farfetchd': 'https://pokeapi.co/api/v2/pokemon/83/',
#  'doduo': 'https://pokeapi.co/api/v2/pokemon/84/',
#  'dodrio': 'https://pokeapi.co/api/v2/pokemon/85/',
#  'seel': 'https://pokeapi.co/api/v2/pokemon/86/',
#  'dewgong': 'https://pokeapi.co/api/v2/pokemon/87/',
#  'grimer': 'https://pokeapi.co/api/v2/pokemon/88/',
#  'muk': 'https://pokeapi.co/api/v2/pokemon/89/',
#  'shellder': 'https://pokeapi.co/api/v2/pokemon/90/',
#  'cloyster': 'https://pokeapi.co/api/v2/pokemon/91/',
#  'gastly': 'https://pokeapi.co/api/v2/pokemon/92/',
#  'haunter': 'https://pokeapi.co/api/v2/pokemon/93/',
#  'gengar': 'https://pokeapi.co/api/v2/pokemon/94/',
#  'onix': 'https://pokeapi.co/api/v2/pokemon/95/',
#  'drowzee': 'https://pokeapi.co/api/v2/pokemon/96/',
#  'hypno': 'https://pokeapi.co/api/v2/pokemon/97/',
#  'krabby': 'https://pokeapi.co/api/v2/pokemon/98/',
#  'kingler': 'https://pokeapi.co/api/v2/pokemon/99/',
#  'voltorb': 'https://pokeapi.co/api/v2/pokemon/100/',
#  'electrode': 'https://pokeapi.co/api/v2/pokemon/101/',
#  'exeggcute': 'https://pokeapi.co/api/v2/pokemon/102/',
#  'exeggutor': 'https://pokeapi.co/api/v2/pokemon/103/',
#  'cubone': 'https://pokeapi.co/api/v2/pokemon/104/',
#  'marowak': 'https://pokeapi.co/api/v2/pokemon/105/',
#  'hitmonlee': 'https://pokeapi.co/api/v2/pokemon/106/',
#  'hitmonchan': 'https://pokeapi.co/api/v2/pokemon/107/',
#  'lickitung': 'https://pokeapi.co/api/v2/pokemon/108/',
#  'koffing': 'https://pokeapi.co/api/v2/pokemon/109/',
#  'weezing': 'https://pokeapi.co/api/v2/pokemon/110/',
#  'rhyhorn': 'https://pokeapi.co/api/v2/pokemon/111/',
#  'rhydon': 'https://pokeapi.co/api/v2/pokemon/112/',
#  'chansey': 'https://pokeapi.co/api/v2/pokemon/113/',
#  'tangela': 'https://pokeapi.co/api/v2/pokemon/114/',
#  'kangaskhan': 'https://pokeapi.co/api/v2/pokemon/115/',
#  'horsea': 'https://pokeapi.co/api/v2/pokemon/116/',
#  'seadra': 'https://pokeapi.co/api/v2/pokemon/117/',
#  'goldeen': 'https://pokeapi.co/api/v2/pokemon/118/',
#  'seaking': 'https://pokeapi.co/api/v2/pokemon/119/',
#  'staryu': 'https://pokeapi.co/api/v2/pokemon/120/',
#  'starmie': 'https://pokeapi.co/api/v2/pokemon/121/',
#  'mr-mime': 'https://pokeapi.co/api/v2/pokemon/122/',
#  'scyther': 'https://pokeapi.co/api/v2/pokemon/123/',
#  'jynx': 'https://pokeapi.co/api/v2/pokemon/124/',
#  'electabuzz': 'https://pokeapi.co/api/v2/pokemon/125/',
#  'magmar': 'https://pokeapi.co/api/v2/pokemon/126/',
#  'pinsir': 'https://pokeapi.co/api/v2/pokemon/127/',
#  'tauros': 'https://pokeapi.co/api/v2/pokemon/128/',
#  'magikarp': 'https://pokeapi.co/api/v2/pokemon/129/',
#  'gyarados': 'https://pokeapi.co/api/v2/pokemon/130/',
#  'lapras': 'https://pokeapi.co/api/v2/pokemon/131/',
#  'ditto': 'https://pokeapi.co/api/v2/pokemon/132/',
#  'eevee': 'https://pokeapi.co/api/v2/pokemon/133/',
#  'vaporeon': 'https://pokeapi.co/api/v2/pokemon/134/',
#  'jolteon': 'https://pokeapi.co/api/v2/pokemon/135/',
#  'flareon': 'https://pokeapi.co/api/v2/pokemon/136/',
#  'porygon': 'https://pokeapi.co/api/v2/pokemon/137/',
#  'omanyte': 'https://pokeapi.co/api/v2/pokemon/138/',
#  'omastar': 'https://pokeapi.co/api/v2/pokemon/139/',
#  'kabuto': 'https://pokeapi.co/api/v2/pokemon/140/',
#  'kabutops': 'https://pokeapi.co/api/v2/pokemon/141/',
#  'aerodactyl': 'https://pokeapi.co/api/v2/pokemon/142/',
#  'snorlax': 'https://pokeapi.co/api/v2/pokemon/143/',
#  'articuno': 'https://pokeapi.co/api/v2/pokemon/144/',
#  'zapdos': 'https://pokeapi.co/api/v2/pokemon/145/',
#  'moltres': 'https://pokeapi.co/api/v2/pokemon/146/',
#  'dratini': 'https://pokeapi.co/api/v2/pokemon/147/',
#  'dragonair': 'https://pokeapi.co/api/v2/pokemon/148/',
#  'dragonite': 'https://pokeapi.co/api/v2/pokemon/149/',
#  'mewtwo': 'https://pokeapi.co/api/v2/pokemon/150/',
#  'mew': 'https://pokeapi.co/api/v2/pokemon/151/',
#  'chikorita': 'https://pokeapi.co/api/v2/pokemon/152/',
#  'bayleef': 'https://pokeapi.co/api/v2/pokemon/153/',
#  'meganium': 'https://pokeapi.co/api/v2/pokemon/154/',
#  'cyndaquil': 'https://pokeapi.co/api/v2/pokemon/155/',
#  'quilava': 'https://pokeapi.co/api/v2/pokemon/156/',
#  'typhlosion': 'https://pokeapi.co/api/v2/pokemon/157/',
#  'totodile': 'https://pokeapi.co/api/v2/pokemon/158/',
#  'croconaw': 'https://pokeapi.co/api/v2/pokemon/159/',
#  'feraligatr': 'https://pokeapi.co/api/v2/pokemon/160/',
#  'sentret': 'https://pokeapi.co/api/v2/pokemon/161/',
#  'furret': 'https://pokeapi.co/api/v2/pokemon/162/',
#  'hoothoot': 'https://pokeapi.co/api/v2/pokemon/163/',
#  'noctowl': 'https://pokeapi.co/api/v2/pokemon/164/',
#  'ledyba': 'https://pokeapi.co/api/v2/pokemon/165/',
#  'ledian': 'https://pokeapi.co/api/v2/pokemon/166/',
#  'spinarak': 'https://pokeapi.co/api/v2/pokemon/167/',
#  'ariados': 'https://pokeapi.co/api/v2/pokemon/168/',
#  'crobat': 'https://pokeapi.co/api/v2/pokemon/169/',
#  'chinchou': 'https://pokeapi.co/api/v2/pokemon/170/',
#  'lanturn': 'https://pokeapi.co/api/v2/pokemon/171/',
#  'pichu': 'https://pokeapi.co/api/v2/pokemon/172/',
#  'cleffa': 'https://pokeapi.co/api/v2/pokemon/173/',
#  'igglybuff': 'https://pokeapi.co/api/v2/pokemon/174/',
#  'togepi': 'https://pokeapi.co/api/v2/pokemon/175/',
#  'togetic': 'https://pokeapi.co/api/v2/pokemon/176/',
#  'natu': 'https://pokeapi.co/api/v2/pokemon/177/',
#  'xatu': 'https://pokeapi.co/api/v2/pokemon/178/',
#  'mareep': 'https://pokeapi.co/api/v2/pokemon/179/',
#  'flaaffy': 'https://pokeapi.co/api/v2/pokemon/180/',
#  'ampharos': 'https://pokeapi.co/api/v2/pokemon/181/',
#  'bellossom': 'https://pokeapi.co/api/v2/pokemon/182/',
#  'marill': 'https://pokeapi.co/api/v2/pokemon/183/',
#  'azumarill': 'https://pokeapi.co/api/v2/pokemon/184/',
#  'sudowoodo': 'https://pokeapi.co/api/v2/pokemon/185/',
#  'politoed': 'https://pokeapi.co/api/v2/pokemon/186/',
#  'hoppip': 'https://pokeapi.co/api/v2/pokemon/187/',
#  'skiploom': 'https://pokeapi.co/api/v2/pokemon/188/',
#  'jumpluff': 'https://pokeapi.co/api/v2/pokemon/189/',
#  'aipom': 'https://pokeapi.co/api/v2/pokemon/190/',
#  'sunkern': 'https://pokeapi.co/api/v2/pokemon/191/',
#  'sunflora': 'https://pokeapi.co/api/v2/pokemon/192/',
#  'yanma': 'https://pokeapi.co/api/v2/pokemon/193/',
#  'wooper': 'https://pokeapi.co/api/v2/pokemon/194/',
#  'quagsire': 'https://pokeapi.co/api/v2/pokemon/195/',
#  'espeon': 'https://pokeapi.co/api/v2/pokemon/196/',
#  'umbreon': 'https://pokeapi.co/api/v2/pokemon/197/',
#  'murkrow': 'https://pokeapi.co/api/v2/pokemon/198/',
#  'slowking': 'https://pokeapi.co/api/v2/pokemon/199/',
#  'misdreavus': 'https://pokeapi.co/api/v2/pokemon/200/',
#  'unown': 'https://pokeapi.co/api/v2/pokemon/201/',
#  'wobbuffet': 'https://pokeapi.co/api/v2/pokemon/202/',
#  'girafarig': 'https://pokeapi.co/api/v2/pokemon/203/',
#  'pineco': 'https://pokeapi.co/api/v2/pokemon/204/',
#  'forretress': 'https://pokeapi.co/api/v2/pokemon/205/',
#  'dunsparce': 'https://pokeapi.co/api/v2/pokemon/206/',
#  'gligar': 'https://pokeapi.co/api/v2/pokemon/207/',
#  'steelix': 'https://pokeapi.co/api/v2/pokemon/208/',
#  'snubbull': 'https://pokeapi.co/api/v2/pokemon/209/',
#  'granbull': 'https://pokeapi.co/api/v2/pokemon/210/',
#  'qwilfish': 'https://pokeapi.co/api/v2/pokemon/211/',
#  'scizor': 'https://pokeapi.co/api/v2/pokemon/212/',
#  'shuckle': 'https://pokeapi.co/api/v2/pokemon/213/',
#  'heracross': 'https://pokeapi.co/api/v2/pokemon/214/',
#  'sneasel': 'https://pokeapi.co/api/v2/pokemon/215/',
#  'teddiursa': 'https://pokeapi.co/api/v2/pokemon/216/',
#  'ursaring': 'https://pokeapi.co/api/v2/pokemon/217/',
#  'slugma': 'https://pokeapi.co/api/v2/pokemon/218/',
#  'magcargo': 'https://pokeapi.co/api/v2/pokemon/219/',
#  'swinub': 'https://pokeapi.co/api/v2/pokemon/220/',
#  'piloswine': 'https://pokeapi.co/api/v2/pokemon/221/',
#  'corsola': 'https://pokeapi.co/api/v2/pokemon/222/',
#  'remoraid': 'https://pokeapi.co/api/v2/pokemon/223/',
#  'octillery': 'https://pokeapi.co/api/v2/pokemon/224/',
#  'delibird': 'https://pokeapi.co/api/v2/pokemon/225/',
#  'mantine': 'https://pokeapi.co/api/v2/pokemon/226/',
#  'skarmory': 'https://pokeapi.co/api/v2/pokemon/227/',
#  'houndour': 'https://pokeapi.co/api/v2/pokemon/228/',
#  'houndoom': 'https://pokeapi.co/api/v2/pokemon/229/',
#  'kingdra': 'https://pokeapi.co/api/v2/pokemon/230/',
#  'phanpy': 'https://pokeapi.co/api/v2/pokemon/231/',
#  'donphan': 'https://pokeapi.co/api/v2/pokemon/232/',
#  'porygon2': 'https://pokeapi.co/api/v2/pokemon/233/',
#  'stantler': 'https://pokeapi.co/api/v2/pokemon/234/',
#  'smeargle': 'https://pokeapi.co/api/v2/pokemon/235/',
#  'tyrogue': 'https://pokeapi.co/api/v2/pokemon/236/',
#  'hitmontop': 'https://pokeapi.co/api/v2/pokemon/237/',
#  'smoochum': 'https://pokeapi.co/api/v2/pokemon/238/',
#  'elekid': 'https://pokeapi.co/api/v2/pokemon/239/',
#  'magby': 'https://pokeapi.co/api/v2/pokemon/240/',
#  'miltank': 'https://pokeapi.co/api/v2/pokemon/241/',
#  'blissey': 'https://pokeapi.co/api/v2/pokemon/242/',
#  'raikou': 'https://pokeapi.co/api/v2/pokemon/243/',
#  'entei': 'https://pokeapi.co/api/v2/pokemon/244/',
#  'suicune': 'https://pokeapi.co/api/v2/pokemon/245/',
#  'larvitar': 'https://pokeapi.co/api/v2/pokemon/246/',
#  'pupitar': 'https://pokeapi.co/api/v2/pokemon/247/',
#  'tyranitar': 'https://pokeapi.co/api/v2/pokemon/248/',
#  'lugia': 'https://pokeapi.co/api/v2/pokemon/249/',
#  'ho-oh': 'https://pokeapi.co/api/v2/pokemon/250/',
#  'celebi': 'https://pokeapi.co/api/v2/pokemon/251/',
#  'treecko': 'https://pokeapi.co/api/v2/pokemon/252/',
#  'grovyle': 'https://pokeapi.co/api/v2/pokemon/253/',
#  'sceptile': 'https://pokeapi.co/api/v2/pokemon/254/',
#  'torchic': 'https://pokeapi.co/api/v2/pokemon/255/',
#  'combusken': 'https://pokeapi.co/api/v2/pokemon/256/',
#  'blaziken': 'https://pokeapi.co/api/v2/pokemon/257/',
#  'mudkip': 'https://pokeapi.co/api/v2/pokemon/258/',
#  'marshtomp': 'https://pokeapi.co/api/v2/pokemon/259/',
#  'swampert': 'https://pokeapi.co/api/v2/pokemon/260/',
#  'poochyena': 'https://pokeapi.co/api/v2/pokemon/261/',
#  'mightyena': 'https://pokeapi.co/api/v2/pokemon/262/',
#  'zigzagoon': 'https://pokeapi.co/api/v2/pokemon/263/',
#  'linoone': 'https://pokeapi.co/api/v2/pokemon/264/',
#  'wurmple': 'https://pokeapi.co/api/v2/pokemon/265/',
#  'silcoon': 'https://pokeapi.co/api/v2/pokemon/266/',
#  'beautifly': 'https://pokeapi.co/api/v2/pokemon/267/',
#  'cascoon': 'https://pokeapi.co/api/v2/pokemon/268/',
#  'dustox': 'https://pokeapi.co/api/v2/pokemon/269/',
#  'lotad': 'https://pokeapi.co/api/v2/pokemon/270/',
#  'lombre': 'https://pokeapi.co/api/v2/pokemon/271/',
#  'ludicolo': 'https://pokeapi.co/api/v2/pokemon/272/',
#  'seedot': 'https://pokeapi.co/api/v2/pokemon/273/',
#  'nuzleaf': 'https://pokeapi.co/api/v2/pokemon/274/',
#  'shiftry': 'https://pokeapi.co/api/v2/pokemon/275/',
#  'taillow': 'https://pokeapi.co/api/v2/pokemon/276/',
#  'swellow': 'https://pokeapi.co/api/v2/pokemon/277/',
#  'wingull': 'https://pokeapi.co/api/v2/pokemon/278/',
#  'pelipper': 'https://pokeapi.co/api/v2/pokemon/279/',
#  'ralts': 'https://pokeapi.co/api/v2/pokemon/280/',
#  'kirlia': 'https://pokeapi.co/api/v2/pokemon/281/',
#  'gardevoir': 'https://pokeapi.co/api/v2/pokemon/282/',
#  'surskit': 'https://pokeapi.co/api/v2/pokemon/283/',
#  'masquerain': 'https://pokeapi.co/api/v2/pokemon/284/',
#  'shroomish': 'https://pokeapi.co/api/v2/pokemon/285/',
#  'breloom': 'https://pokeapi.co/api/v2/pokemon/286/',
#  'slakoth': 'https://pokeapi.co/api/v2/pokemon/287/',
#  'vigoroth': 'https://pokeapi.co/api/v2/pokemon/288/',
#  'slaking': 'https://pokeapi.co/api/v2/pokemon/289/',
#  'nincada': 'https://pokeapi.co/api/v2/pokemon/290/',
#  'ninjask': 'https://pokeapi.co/api/v2/pokemon/291/',
#  'shedinja': 'https://pokeapi.co/api/v2/pokemon/292/',
#  'whismur': 'https://pokeapi.co/api/v2/pokemon/293/',
#  'loudred': 'https://pokeapi.co/api/v2/pokemon/294/',
#  'exploud': 'https://pokeapi.co/api/v2/pokemon/295/',
#  'makuhita': 'https://pokeapi.co/api/v2/pokemon/296/',
#  'hariyama': 'https://pokeapi.co/api/v2/pokemon/297/',
#  'azurill': 'https://pokeapi.co/api/v2/pokemon/298/',
#  'nosepass': 'https://pokeapi.co/api/v2/pokemon/299/',
#  'skitty': 'https://pokeapi.co/api/v2/pokemon/300/',
#  'delcatty': 'https://pokeapi.co/api/v2/pokemon/301/',
#  'sableye': 'https://pokeapi.co/api/v2/pokemon/302/',
#  'mawile': 'https://pokeapi.co/api/v2/pokemon/303/',
#  'aron': 'https://pokeapi.co/api/v2/pokemon/304/',
#  'lairon': 'https://pokeapi.co/api/v2/pokemon/305/',
#  'aggron': 'https://pokeapi.co/api/v2/pokemon/306/',
#  'meditite': 'https://pokeapi.co/api/v2/pokemon/307/',
#  'medicham': 'https://pokeapi.co/api/v2/pokemon/308/',
#  'electrike': 'https://pokeapi.co/api/v2/pokemon/309/',
#  'manectric': 'https://pokeapi.co/api/v2/pokemon/310/',
#  'plusle': 'https://pokeapi.co/api/v2/pokemon/311/',
#  'minun': 'https://pokeapi.co/api/v2/pokemon/312/',
#  'volbeat': 'https://pokeapi.co/api/v2/pokemon/313/',
#  'illumise': 'https://pokeapi.co/api/v2/pokemon/314/',
#  'roselia': 'https://pokeapi.co/api/v2/pokemon/315/',
#  'gulpin': 'https://pokeapi.co/api/v2/pokemon/316/',
#  'swalot': 'https://pokeapi.co/api/v2/pokemon/317/',
#  'carvanha': 'https://pokeapi.co/api/v2/pokemon/318/',
#  'sharpedo': 'https://pokeapi.co/api/v2/pokemon/319/',
#  'wailmer': 'https://pokeapi.co/api/v2/pokemon/320/',
#  'wailord': 'https://pokeapi.co/api/v2/pokemon/321/',
#  'numel': 'https://pokeapi.co/api/v2/pokemon/322/',
#  'camerupt': 'https://pokeapi.co/api/v2/pokemon/323/',
#  'torkoal': 'https://pokeapi.co/api/v2/pokemon/324/',
#  'spoink': 'https://pokeapi.co/api/v2/pokemon/325/',
#  'grumpig': 'https://pokeapi.co/api/v2/pokemon/326/',
#  'spinda': 'https://pokeapi.co/api/v2/pokemon/327/',
#  'trapinch': 'https://pokeapi.co/api/v2/pokemon/328/',
#  'vibrava': 'https://pokeapi.co/api/v2/pokemon/329/',
#  'flygon': 'https://pokeapi.co/api/v2/pokemon/330/',
#  'cacnea': 'https://pokeapi.co/api/v2/pokemon/331/',
#  'cacturne': 'https://pokeapi.co/api/v2/pokemon/332/',
#  'swablu': 'https://pokeapi.co/api/v2/pokemon/333/',
#  'altaria': 'https://pokeapi.co/api/v2/pokemon/334/',
#  'zangoose': 'https://pokeapi.co/api/v2/pokemon/335/',
#  'seviper': 'https://pokeapi.co/api/v2/pokemon/336/',
#  'lunatone': 'https://pokeapi.co/api/v2/pokemon/337/',
#  'solrock': 'https://pokeapi.co/api/v2/pokemon/338/',
#  'barboach': 'https://pokeapi.co/api/v2/pokemon/339/',
#  'whiscash': 'https://pokeapi.co/api/v2/pokemon/340/',
#  'corphish': 'https://pokeapi.co/api/v2/pokemon/341/',
#  'crawdaunt': 'https://pokeapi.co/api/v2/pokemon/342/',
#  'baltoy': 'https://pokeapi.co/api/v2/pokemon/343/',
#  'claydol': 'https://pokeapi.co/api/v2/pokemon/344/',
#  'lileep': 'https://pokeapi.co/api/v2/pokemon/345/',
#  'cradily': 'https://pokeapi.co/api/v2/pokemon/346/',
#  'anorith': 'https://pokeapi.co/api/v2/pokemon/347/',
#  'armaldo': 'https://pokeapi.co/api/v2/pokemon/348/',
#  'feebas': 'https://pokeapi.co/api/v2/pokemon/349/',
#  'milotic': 'https://pokeapi.co/api/v2/pokemon/350/',
#  'castform': 'https://pokeapi.co/api/v2/pokemon/351/',
#  'kecleon': 'https://pokeapi.co/api/v2/pokemon/352/',
#  'shuppet': 'https://pokeapi.co/api/v2/pokemon/353/',
#  'banette': 'https://pokeapi.co/api/v2/pokemon/354/',
#  'duskull': 'https://pokeapi.co/api/v2/pokemon/355/',
#  'dusclops': 'https://pokeapi.co/api/v2/pokemon/356/',
#  'tropius': 'https://pokeapi.co/api/v2/pokemon/357/',
#  'chimecho': 'https://pokeapi.co/api/v2/pokemon/358/',
#  'absol': 'https://pokeapi.co/api/v2/pokemon/359/',
#  'wynaut': 'https://pokeapi.co/api/v2/pokemon/360/',
#  'snorunt': 'https://pokeapi.co/api/v2/pokemon/361/',
#  'glalie': 'https://pokeapi.co/api/v2/pokemon/362/',
#  'spheal': 'https://pokeapi.co/api/v2/pokemon/363/',
#  'sealeo': 'https://pokeapi.co/api/v2/pokemon/364/',
#  'walrein': 'https://pokeapi.co/api/v2/pokemon/365/',
#  'clamperl': 'https://pokeapi.co/api/v2/pokemon/366/',
#  'huntail': 'https://pokeapi.co/api/v2/pokemon/367/',
#  'gorebyss': 'https://pokeapi.co/api/v2/pokemon/368/',
#  'relicanth': 'https://pokeapi.co/api/v2/pokemon/369/',
#  'luvdisc': 'https://pokeapi.co/api/v2/pokemon/370/',
#  'bagon': 'https://pokeapi.co/api/v2/pokemon/371/',
#  'shelgon': 'https://pokeapi.co/api/v2/pokemon/372/',
#  'salamence': 'https://pokeapi.co/api/v2/pokemon/373/',
#  'beldum': 'https://pokeapi.co/api/v2/pokemon/374/',
#  'metang': 'https://pokeapi.co/api/v2/pokemon/375/',
#  'metagross': 'https://pokeapi.co/api/v2/pokemon/376/',
#  'regirock': 'https://pokeapi.co/api/v2/pokemon/377/',
#  'regice': 'https://pokeapi.co/api/v2/pokemon/378/',
#  'registeel': 'https://pokeapi.co/api/v2/pokemon/379/',
#  'latias': 'https://pokeapi.co/api/v2/pokemon/380/',
#  'latios': 'https://pokeapi.co/api/v2/pokemon/381/',
#  'kyogre': 'https://pokeapi.co/api/v2/pokemon/382/',
#  'groudon': 'https://pokeapi.co/api/v2/pokemon/383/',
#  'rayquaza': 'https://pokeapi.co/api/v2/pokemon/384/',
#  'jirachi': 'https://pokeapi.co/api/v2/pokemon/385/',
#  'deoxys-normal': 'https://pokeapi.co/api/v2/pokemon/386/',
#  'turtwig': 'https://pokeapi.co/api/v2/pokemon/387/',
#  'grotle': 'https://pokeapi.co/api/v2/pokemon/388/',
#  'torterra': 'https://pokeapi.co/api/v2/pokemon/389/',
#  'chimchar': 'https://pokeapi.co/api/v2/pokemon/390/',
#  'monferno': 'https://pokeapi.co/api/v2/pokemon/391/',
#  'infernape': 'https://pokeapi.co/api/v2/pokemon/392/',
#  'piplup': 'https://pokeapi.co/api/v2/pokemon/393/',
#  'prinplup': 'https://pokeapi.co/api/v2/pokemon/394/',
#  'empoleon': 'https://pokeapi.co/api/v2/pokemon/395/',
#  'starly': 'https://pokeapi.co/api/v2/pokemon/396/',
#  'staravia': 'https://pokeapi.co/api/v2/pokemon/397/',
#  'staraptor': 'https://pokeapi.co/api/v2/pokemon/398/',
#  'bidoof': 'https://pokeapi.co/api/v2/pokemon/399/',
#  'bibarel': 'https://pokeapi.co/api/v2/pokemon/400/',
#  'kricketot': 'https://pokeapi.co/api/v2/pokemon/401/',
#  'kricketune': 'https://pokeapi.co/api/v2/pokemon/402/',
#  'shinx': 'https://pokeapi.co/api/v2/pokemon/403/',
#  'luxio': 'https://pokeapi.co/api/v2/pokemon/404/',
#  'luxray': 'https://pokeapi.co/api/v2/pokemon/405/',
#  'budew': 'https://pokeapi.co/api/v2/pokemon/406/',
#  'roserade': 'https://pokeapi.co/api/v2/pokemon/407/',
#  'cranidos': 'https://pokeapi.co/api/v2/pokemon/408/',
#  'rampardos': 'https://pokeapi.co/api/v2/pokemon/409/',
#  'shieldon': 'https://pokeapi.co/api/v2/pokemon/410/',
#  'bastiodon': 'https://pokeapi.co/api/v2/pokemon/411/',
#  'burmy': 'https://pokeapi.co/api/v2/pokemon/412/',
#  'wormadam-plant': 'https://pokeapi.co/api/v2/pokemon/413/',
#  'mothim': 'https://pokeapi.co/api/v2/pokemon/414/',
#  'combee': 'https://pokeapi.co/api/v2/pokemon/415/',
#  'vespiquen': 'https://pokeapi.co/api/v2/pokemon/416/',
#  'pachirisu': 'https://pokeapi.co/api/v2/pokemon/417/',
#  'buizel': 'https://pokeapi.co/api/v2/pokemon/418/',
#  'floatzel': 'https://pokeapi.co/api/v2/pokemon/419/',
#  'cherubi': 'https://pokeapi.co/api/v2/pokemon/420/',
#  'cherrim': 'https://pokeapi.co/api/v2/pokemon/421/',
#  'shellos': 'https://pokeapi.co/api/v2/pokemon/422/',
#  'gastrodon': 'https://pokeapi.co/api/v2/pokemon/423/',
#  'ambipom': 'https://pokeapi.co/api/v2/pokemon/424/',
#  'drifloon': 'https://pokeapi.co/api/v2/pokemon/425/',
#  'drifblim': 'https://pokeapi.co/api/v2/pokemon/426/',
#  'buneary': 'https://pokeapi.co/api/v2/pokemon/427/',
#  'lopunny': 'https://pokeapi.co/api/v2/pokemon/428/',
#  'mismagius': 'https://pokeapi.co/api/v2/pokemon/429/',
#  'honchkrow': 'https://pokeapi.co/api/v2/pokemon/430/',
#  'glameow': 'https://pokeapi.co/api/v2/pokemon/431/',
#  'purugly': 'https://pokeapi.co/api/v2/pokemon/432/',
#  'chingling': 'https://pokeapi.co/api/v2/pokemon/433/',
#  'stunky': 'https://pokeapi.co/api/v2/pokemon/434/',
#  'skuntank': 'https://pokeapi.co/api/v2/pokemon/435/',
#  'bronzor': 'https://pokeapi.co/api/v2/pokemon/436/',
#  'bronzong': 'https://pokeapi.co/api/v2/pokemon/437/',
#  'bonsly': 'https://pokeapi.co/api/v2/pokemon/438/',
#  'mime-jr': 'https://pokeapi.co/api/v2/pokemon/439/',
#  'happiny': 'https://pokeapi.co/api/v2/pokemon/440/',
#  'chatot': 'https://pokeapi.co/api/v2/pokemon/441/',
#  'spiritomb': 'https://pokeapi.co/api/v2/pokemon/442/',
#  'gible': 'https://pokeapi.co/api/v2/pokemon/443/',
#  'gabite': 'https://pokeapi.co/api/v2/pokemon/444/',
#  'garchomp': 'https://pokeapi.co/api/v2/pokemon/445/',
#  'munchlax': 'https://pokeapi.co/api/v2/pokemon/446/',
#  'riolu': 'https://pokeapi.co/api/v2/pokemon/447/',
#  'lucario': 'https://pokeapi.co/api/v2/pokemon/448/',
#  'hippopotas': 'https://pokeapi.co/api/v2/pokemon/449/',
#  'hippowdon': 'https://pokeapi.co/api/v2/pokemon/450/',
#  'skorupi': 'https://pokeapi.co/api/v2/pokemon/451/',
#  'drapion': 'https://pokeapi.co/api/v2/pokemon/452/',
#  'croagunk': 'https://pokeapi.co/api/v2/pokemon/453/',
#  'toxicroak': 'https://pokeapi.co/api/v2/pokemon/454/',
#  'carnivine': 'https://pokeapi.co/api/v2/pokemon/455/',
#  'finneon': 'https://pokeapi.co/api/v2/pokemon/456/',
#  'lumineon': 'https://pokeapi.co/api/v2/pokemon/457/',
#  'mantyke': 'https://pokeapi.co/api/v2/pokemon/458/',
#  'snover': 'https://pokeapi.co/api/v2/pokemon/459/',
#  'abomasnow': 'https://pokeapi.co/api/v2/pokemon/460/',
#  'weavile': 'https://pokeapi.co/api/v2/pokemon/461/',
#  'magnezone': 'https://pokeapi.co/api/v2/pokemon/462/',
#  'lickilicky': 'https://pokeapi.co/api/v2/pokemon/463/',
#  'rhyperior': 'https://pokeapi.co/api/v2/pokemon/464/',
#  'tangrowth': 'https://pokeapi.co/api/v2/pokemon/465/',
#  'electivire': 'https://pokeapi.co/api/v2/pokemon/466/',
#  'magmortar': 'https://pokeapi.co/api/v2/pokemon/467/',
#  'togekiss': 'https://pokeapi.co/api/v2/pokemon/468/',
#  'yanmega': 'https://pokeapi.co/api/v2/pokemon/469/',
#  'leafeon': 'https://pokeapi.co/api/v2/pokemon/470/',
#  'glaceon': 'https://pokeapi.co/api/v2/pokemon/471/',
#  'gliscor': 'https://pokeapi.co/api/v2/pokemon/472/',
#  'mamoswine': 'https://pokeapi.co/api/v2/pokemon/473/',
#  'porygon-z': 'https://pokeapi.co/api/v2/pokemon/474/',
#  'gallade': 'https://pokeapi.co/api/v2/pokemon/475/',
#  'probopass': 'https://pokeapi.co/api/v2/pokemon/476/',
#  'dusknoir': 'https://pokeapi.co/api/v2/pokemon/477/',
#  'froslass': 'https://pokeapi.co/api/v2/pokemon/478/',
#  'rotom': 'https://pokeapi.co/api/v2/pokemon/479/',
#  'uxie': 'https://pokeapi.co/api/v2/pokemon/480/',
#  'mesprit': 'https://pokeapi.co/api/v2/pokemon/481/',
#  'azelf': 'https://pokeapi.co/api/v2/pokemon/482/',
#  'dialga': 'https://pokeapi.co/api/v2/pokemon/483/',
#  'palkia': 'https://pokeapi.co/api/v2/pokemon/484/',
#  'heatran': 'https://pokeapi.co/api/v2/pokemon/485/',
#  'regigigas': 'https://pokeapi.co/api/v2/pokemon/486/',
#  'giratina-altered': 'https://pokeapi.co/api/v2/pokemon/487/',
#  'cresselia': 'https://pokeapi.co/api/v2/pokemon/488/',
#  'phione': 'https://pokeapi.co/api/v2/pokemon/489/',
#  'manaphy': 'https://pokeapi.co/api/v2/pokemon/490/',
#  'darkrai': 'https://pokeapi.co/api/v2/pokemon/491/',
#  'shaymin-land': 'https://pokeapi.co/api/v2/pokemon/492/',
#  'arceus': 'https://pokeapi.co/api/v2/pokemon/493/',
#  'victini': 'https://pokeapi.co/api/v2/pokemon/494/',
#  'snivy': 'https://pokeapi.co/api/v2/pokemon/495/',
#  'servine': 'https://pokeapi.co/api/v2/pokemon/496/',
#  'serperior': 'https://pokeapi.co/api/v2/pokemon/497/',
#  'tepig': 'https://pokeapi.co/api/v2/pokemon/498/',
#  'pignite': 'https://pokeapi.co/api/v2/pokemon/499/',
#  'emboar': 'https://pokeapi.co/api/v2/pokemon/500/',
#  'oshawott': 'https://pokeapi.co/api/v2/pokemon/501/',
#  'dewott': 'https://pokeapi.co/api/v2/pokemon/502/',
#  'samurott': 'https://pokeapi.co/api/v2/pokemon/503/',
#  'patrat': 'https://pokeapi.co/api/v2/pokemon/504/',
#  'watchog': 'https://pokeapi.co/api/v2/pokemon/505/',
#  'lillipup': 'https://pokeapi.co/api/v2/pokemon/506/',
#  'herdier': 'https://pokeapi.co/api/v2/pokemon/507/',
#  'stoutland': 'https://pokeapi.co/api/v2/pokemon/508/',
#  'purrloin': 'https://pokeapi.co/api/v2/pokemon/509/',
#  'liepard': 'https://pokeapi.co/api/v2/pokemon/510/',
#  'pansage': 'https://pokeapi.co/api/v2/pokemon/511/',
#  'simisage': 'https://pokeapi.co/api/v2/pokemon/512/',
#  'pansear': 'https://pokeapi.co/api/v2/pokemon/513/',
#  'simisear': 'https://pokeapi.co/api/v2/pokemon/514/',
#  'panpour': 'https://pokeapi.co/api/v2/pokemon/515/',
#  'simipour': 'https://pokeapi.co/api/v2/pokemon/516/',
#  'munna': 'https://pokeapi.co/api/v2/pokemon/517/',
#  'musharna': 'https://pokeapi.co/api/v2/pokemon/518/',
#  'pidove': 'https://pokeapi.co/api/v2/pokemon/519/',
#  'tranquill': 'https://pokeapi.co/api/v2/pokemon/520/',
#  'unfezant': 'https://pokeapi.co/api/v2/pokemon/521/',
#  'blitzle': 'https://pokeapi.co/api/v2/pokemon/522/',
#  'zebstrika': 'https://pokeapi.co/api/v2/pokemon/523/',
#  'roggenrola': 'https://pokeapi.co/api/v2/pokemon/524/',
#  'boldore': 'https://pokeapi.co/api/v2/pokemon/525/',
#  'gigalith': 'https://pokeapi.co/api/v2/pokemon/526/',
#  'woobat': 'https://pokeapi.co/api/v2/pokemon/527/',
#  'swoobat': 'https://pokeapi.co/api/v2/pokemon/528/',
#  'drilbur': 'https://pokeapi.co/api/v2/pokemon/529/',
#  'excadrill': 'https://pokeapi.co/api/v2/pokemon/530/',
#  'audino': 'https://pokeapi.co/api/v2/pokemon/531/',
#  'timburr': 'https://pokeapi.co/api/v2/pokemon/532/',
#  'gurdurr': 'https://pokeapi.co/api/v2/pokemon/533/',
#  'conkeldurr': 'https://pokeapi.co/api/v2/pokemon/534/',
#  'tympole': 'https://pokeapi.co/api/v2/pokemon/535/',
#  'palpitoad': 'https://pokeapi.co/api/v2/pokemon/536/',
#  'seismitoad': 'https://pokeapi.co/api/v2/pokemon/537/',
#  'throh': 'https://pokeapi.co/api/v2/pokemon/538/',
#  'sawk': 'https://pokeapi.co/api/v2/pokemon/539/',
#  'sewaddle': 'https://pokeapi.co/api/v2/pokemon/540/',
#  'swadloon': 'https://pokeapi.co/api/v2/pokemon/541/',
#  'leavanny': 'https://pokeapi.co/api/v2/pokemon/542/',
#  'venipede': 'https://pokeapi.co/api/v2/pokemon/543/',
#  'whirlipede': 'https://pokeapi.co/api/v2/pokemon/544/',
#  'scolipede': 'https://pokeapi.co/api/v2/pokemon/545/',
#  'cottonee': 'https://pokeapi.co/api/v2/pokemon/546/',
#  'whimsicott': 'https://pokeapi.co/api/v2/pokemon/547/',
#  'petilil': 'https://pokeapi.co/api/v2/pokemon/548/',
#  'lilligant': 'https://pokeapi.co/api/v2/pokemon/549/',
#  'basculin-red-striped': 'https://pokeapi.co/api/v2/pokemon/550/',
#  'sandile': 'https://pokeapi.co/api/v2/pokemon/551/',
#  'krokorok': 'https://pokeapi.co/api/v2/pokemon/552/',
#  'krookodile': 'https://pokeapi.co/api/v2/pokemon/553/',
#  'darumaka': 'https://pokeapi.co/api/v2/pokemon/554/',
#  'darmanitan-standard': 'https://pokeapi.co/api/v2/pokemon/555/',
#  'maractus': 'https://pokeapi.co/api/v2/pokemon/556/',
#  'dwebble': 'https://pokeapi.co/api/v2/pokemon/557/',
#  'crustle': 'https://pokeapi.co/api/v2/pokemon/558/',
#  'scraggy': 'https://pokeapi.co/api/v2/pokemon/559/',
#  'scrafty': 'https://pokeapi.co/api/v2/pokemon/560/',
#  'sigilyph': 'https://pokeapi.co/api/v2/pokemon/561/',
#  'yamask': 'https://pokeapi.co/api/v2/pokemon/562/',
#  'cofagrigus': 'https://pokeapi.co/api/v2/pokemon/563/',
#  'tirtouga': 'https://pokeapi.co/api/v2/pokemon/564/',
#  'carracosta': 'https://pokeapi.co/api/v2/pokemon/565/',
#  'archen': 'https://pokeapi.co/api/v2/pokemon/566/',
#  'archeops': 'https://pokeapi.co/api/v2/pokemon/567/',
#  'trubbish': 'https://pokeapi.co/api/v2/pokemon/568/',
#  'garbodor': 'https://pokeapi.co/api/v2/pokemon/569/',
#  'zorua': 'https://pokeapi.co/api/v2/pokemon/570/',
#  'zoroark': 'https://pokeapi.co/api/v2/pokemon/571/',
#  'minccino': 'https://pokeapi.co/api/v2/pokemon/572/',
#  'cinccino': 'https://pokeapi.co/api/v2/pokemon/573/',
#  'gothita': 'https://pokeapi.co/api/v2/pokemon/574/',
#  'gothorita': 'https://pokeapi.co/api/v2/pokemon/575/',
#  'gothitelle': 'https://pokeapi.co/api/v2/pokemon/576/',
#  'solosis': 'https://pokeapi.co/api/v2/pokemon/577/',
#  'duosion': 'https://pokeapi.co/api/v2/pokemon/578/',
#  'reuniclus': 'https://pokeapi.co/api/v2/pokemon/579/',
#  'ducklett': 'https://pokeapi.co/api/v2/pokemon/580/',
#  'swanna': 'https://pokeapi.co/api/v2/pokemon/581/',
#  'vanillite': 'https://pokeapi.co/api/v2/pokemon/582/',
#  'vanillish': 'https://pokeapi.co/api/v2/pokemon/583/',
#  'vanilluxe': 'https://pokeapi.co/api/v2/pokemon/584/',
#  'deerling': 'https://pokeapi.co/api/v2/pokemon/585/',
#  'sawsbuck': 'https://pokeapi.co/api/v2/pokemon/586/',
#  'emolga': 'https://pokeapi.co/api/v2/pokemon/587/',
#  'karrablast': 'https://pokeapi.co/api/v2/pokemon/588/',
#  'escavalier': 'https://pokeapi.co/api/v2/pokemon/589/',
#  'foongus': 'https://pokeapi.co/api/v2/pokemon/590/',
#  'amoonguss': 'https://pokeapi.co/api/v2/pokemon/591/',
#  'frillish': 'https://pokeapi.co/api/v2/pokemon/592/',
#  'jellicent': 'https://pokeapi.co/api/v2/pokemon/593/',
#  'alomomola': 'https://pokeapi.co/api/v2/pokemon/594/',
#  'joltik': 'https://pokeapi.co/api/v2/pokemon/595/',
#  'galvantula': 'https://pokeapi.co/api/v2/pokemon/596/',
#  'ferroseed': 'https://pokeapi.co/api/v2/pokemon/597/',
#  'ferrothorn': 'https://pokeapi.co/api/v2/pokemon/598/',
#  'klink': 'https://pokeapi.co/api/v2/pokemon/599/',
#  'klang': 'https://pokeapi.co/api/v2/pokemon/600/',
#  'klinklang': 'https://pokeapi.co/api/v2/pokemon/601/',
#  'tynamo': 'https://pokeapi.co/api/v2/pokemon/602/',
#  'eelektrik': 'https://pokeapi.co/api/v2/pokemon/603/',
#  'eelektross': 'https://pokeapi.co/api/v2/pokemon/604/',
#  'elgyem': 'https://pokeapi.co/api/v2/pokemon/605/',
#  'beheeyem': 'https://pokeapi.co/api/v2/pokemon/606/',
#  'litwick': 'https://pokeapi.co/api/v2/pokemon/607/',
#  'lampent': 'https://pokeapi.co/api/v2/pokemon/608/',
#  'chandelure': 'https://pokeapi.co/api/v2/pokemon/609/',
#  'axew': 'https://pokeapi.co/api/v2/pokemon/610/',
#  'fraxure': 'https://pokeapi.co/api/v2/pokemon/611/',
#  'haxorus': 'https://pokeapi.co/api/v2/pokemon/612/',
#  'cubchoo': 'https://pokeapi.co/api/v2/pokemon/613/',
#  'beartic': 'https://pokeapi.co/api/v2/pokemon/614/',
#  'cryogonal': 'https://pokeapi.co/api/v2/pokemon/615/',
#  'shelmet': 'https://pokeapi.co/api/v2/pokemon/616/',
#  'accelgor': 'https://pokeapi.co/api/v2/pokemon/617/',
#  'stunfisk': 'https://pokeapi.co/api/v2/pokemon/618/',
#  'mienfoo': 'https://pokeapi.co/api/v2/pokemon/619/',
#  'mienshao': 'https://pokeapi.co/api/v2/pokemon/620/',
#  'druddigon': 'https://pokeapi.co/api/v2/pokemon/621/',
#  'golett': 'https://pokeapi.co/api/v2/pokemon/622/',
#  'golurk': 'https://pokeapi.co/api/v2/pokemon/623/',
#  'pawniard': 'https://pokeapi.co/api/v2/pokemon/624/',
#  'bisharp': 'https://pokeapi.co/api/v2/pokemon/625/',
#  'bouffalant': 'https://pokeapi.co/api/v2/pokemon/626/',
#  'rufflet': 'https://pokeapi.co/api/v2/pokemon/627/',
#  'braviary': 'https://pokeapi.co/api/v2/pokemon/628/',
#  'vullaby': 'https://pokeapi.co/api/v2/pokemon/629/',
#  'mandibuzz': 'https://pokeapi.co/api/v2/pokemon/630/',
#  'heatmor': 'https://pokeapi.co/api/v2/pokemon/631/',
#  'durant': 'https://pokeapi.co/api/v2/pokemon/632/',
#  'deino': 'https://pokeapi.co/api/v2/pokemon/633/',
#  'zweilous': 'https://pokeapi.co/api/v2/pokemon/634/',
#  'hydreigon': 'https://pokeapi.co/api/v2/pokemon/635/',
#  'larvesta': 'https://pokeapi.co/api/v2/pokemon/636/',
#  'volcarona': 'https://pokeapi.co/api/v2/pokemon/637/',
#  'cobalion': 'https://pokeapi.co/api/v2/pokemon/638/',
#  'terrakion': 'https://pokeapi.co/api/v2/pokemon/639/',
#  'virizion': 'https://pokeapi.co/api/v2/pokemon/640/',
#  'tornadus-incarnate': 'https://pokeapi.co/api/v2/pokemon/641/',
#  'thundurus-incarnate': 'https://pokeapi.co/api/v2/pokemon/642/',
#  'reshiram': 'https://pokeapi.co/api/v2/pokemon/643/',
#  'zekrom': 'https://pokeapi.co/api/v2/pokemon/644/',
#  'landorus-incarnate': 'https://pokeapi.co/api/v2/pokemon/645/',
#  'kyurem': 'https://pokeapi.co/api/v2/pokemon/646/',
#  'keldeo-ordinary': 'https://pokeapi.co/api/v2/pokemon/647/',
#  'meloetta-aria': 'https://pokeapi.co/api/v2/pokemon/648/',
#  'genesect': 'https://pokeapi.co/api/v2/pokemon/649/',
#  'chespin': 'https://pokeapi.co/api/v2/pokemon/650/',
#  'quilladin': 'https://pokeapi.co/api/v2/pokemon/651/',
#  'chesnaught': 'https://pokeapi.co/api/v2/pokemon/652/',
#  'fennekin': 'https://pokeapi.co/api/v2/pokemon/653/',
#  'braixen': 'https://pokeapi.co/api/v2/pokemon/654/',
#  'delphox': 'https://pokeapi.co/api/v2/pokemon/655/',
#  'froakie': 'https://pokeapi.co/api/v2/pokemon/656/',
#  'frogadier': 'https://pokeapi.co/api/v2/pokemon/657/',
#  'greninja': 'https://pokeapi.co/api/v2/pokemon/658/',
#  'bunnelby': 'https://pokeapi.co/api/v2/pokemon/659/',
#  'diggersby': 'https://pokeapi.co/api/v2/pokemon/660/',
#  'fletchling': 'https://pokeapi.co/api/v2/pokemon/661/',
#  'fletchinder': 'https://pokeapi.co/api/v2/pokemon/662/',
#  'talonflame': 'https://pokeapi.co/api/v2/pokemon/663/',
#  'scatterbug': 'https://pokeapi.co/api/v2/pokemon/664/',
#  'spewpa': 'https://pokeapi.co/api/v2/pokemon/665/',
#  'vivillon': 'https://pokeapi.co/api/v2/pokemon/666/',
#  'litleo': 'https://pokeapi.co/api/v2/pokemon/667/',
#  'pyroar': 'https://pokeapi.co/api/v2/pokemon/668/',
#  'flabebe': 'https://pokeapi.co/api/v2/pokemon/669/',
#  'floette': 'https://pokeapi.co/api/v2/pokemon/670/',
#  'florges': 'https://pokeapi.co/api/v2/pokemon/671/',
#  'skiddo': 'https://pokeapi.co/api/v2/pokemon/672/',
#  'gogoat': 'https://pokeapi.co/api/v2/pokemon/673/',
#  'pancham': 'https://pokeapi.co/api/v2/pokemon/674/',
#  'pangoro': 'https://pokeapi.co/api/v2/pokemon/675/',
#  'furfrou': 'https://pokeapi.co/api/v2/pokemon/676/',
#  'espurr': 'https://pokeapi.co/api/v2/pokemon/677/',
#  'meowstic-male': 'https://pokeapi.co/api/v2/pokemon/678/',
#  'honedge': 'https://pokeapi.co/api/v2/pokemon/679/',
#  'doublade': 'https://pokeapi.co/api/v2/pokemon/680/',
#  'aegislash-shield': 'https://pokeapi.co/api/v2/pokemon/681/',
#  'spritzee': 'https://pokeapi.co/api/v2/pokemon/682/',
#  'aromatisse': 'https://pokeapi.co/api/v2/pokemon/683/',
#  'swirlix': 'https://pokeapi.co/api/v2/pokemon/684/',
#  'slurpuff': 'https://pokeapi.co/api/v2/pokemon/685/',
#  'inkay': 'https://pokeapi.co/api/v2/pokemon/686/',
#  'malamar': 'https://pokeapi.co/api/v2/pokemon/687/',
#  'binacle': 'https://pokeapi.co/api/v2/pokemon/688/',
#  'barbaracle': 'https://pokeapi.co/api/v2/pokemon/689/',
#  'skrelp': 'https://pokeapi.co/api/v2/pokemon/690/',
#  'dragalge': 'https://pokeapi.co/api/v2/pokemon/691/',
#  'clauncher': 'https://pokeapi.co/api/v2/pokemon/692/',
#  'clawitzer': 'https://pokeapi.co/api/v2/pokemon/693/',
#  'helioptile': 'https://pokeapi.co/api/v2/pokemon/694/',
#  'heliolisk': 'https://pokeapi.co/api/v2/pokemon/695/',
#  'tyrunt': 'https://pokeapi.co/api/v2/pokemon/696/',
#  'tyrantrum': 'https://pokeapi.co/api/v2/pokemon/697/',
#  'amaura': 'https://pokeapi.co/api/v2/pokemon/698/',
#  'aurorus': 'https://pokeapi.co/api/v2/pokemon/699/',
#  'sylveon': 'https://pokeapi.co/api/v2/pokemon/700/',
#  'hawlucha': 'https://pokeapi.co/api/v2/pokemon/701/',
#  'dedenne': 'https://pokeapi.co/api/v2/pokemon/702/',
#  'carbink': 'https://pokeapi.co/api/v2/pokemon/703/',
#  'goomy': 'https://pokeapi.co/api/v2/pokemon/704/',
#  'sliggoo': 'https://pokeapi.co/api/v2/pokemon/705/',
#  'goodra': 'https://pokeapi.co/api/v2/pokemon/706/',
#  'klefki': 'https://pokeapi.co/api/v2/pokemon/707/',
#  'phantump': 'https://pokeapi.co/api/v2/pokemon/708/',
#  'trevenant': 'https://pokeapi.co/api/v2/pokemon/709/',
#  'pumpkaboo-average': 'https://pokeapi.co/api/v2/pokemon/710/',
#  'gourgeist-average': 'https://pokeapi.co/api/v2/pokemon/711/',
#  'bergmite': 'https://pokeapi.co/api/v2/pokemon/712/',
#  'avalugg': 'https://pokeapi.co/api/v2/pokemon/713/',
#  'noibat': 'https://pokeapi.co/api/v2/pokemon/714/',
#  'noivern': 'https://pokeapi.co/api/v2/pokemon/715/',
#  'xerneas': 'https://pokeapi.co/api/v2/pokemon/716/',
#  'yveltal': 'https://pokeapi.co/api/v2/pokemon/717/',
#  'zygarde': 'https://pokeapi.co/api/v2/pokemon/718/',
#  'diancie': 'https://pokeapi.co/api/v2/pokemon/719/',
#  'hoopa': 'https://pokeapi.co/api/v2/pokemon/720/',
#  'volcanion': 'https://pokeapi.co/api/v2/pokemon/721/',
#  'rowlet': 'https://pokeapi.co/api/v2/pokemon/722/',
#  'dartrix': 'https://pokeapi.co/api/v2/pokemon/723/',
#  'decidueye': 'https://pokeapi.co/api/v2/pokemon/724/',
#  'litten': 'https://pokeapi.co/api/v2/pokemon/725/',
#  'torracat': 'https://pokeapi.co/api/v2/pokemon/726/',
#  'incineroar': 'https://pokeapi.co/api/v2/pokemon/727/',
#  'popplio': 'https://pokeapi.co/api/v2/pokemon/728/',
#  'brionne': 'https://pokeapi.co/api/v2/pokemon/729/',
#  'primarina': 'https://pokeapi.co/api/v2/pokemon/730/',
#  'pikipek': 'https://pokeapi.co/api/v2/pokemon/731/',
#  'trumbeak': 'https://pokeapi.co/api/v2/pokemon/732/',
#  'toucannon': 'https://pokeapi.co/api/v2/pokemon/733/',
#  'yungoos': 'https://pokeapi.co/api/v2/pokemon/734/',
#  'gumshoos': 'https://pokeapi.co/api/v2/pokemon/735/',
#  'grubbin': 'https://pokeapi.co/api/v2/pokemon/736/',
#  'charjabug': 'https://pokeapi.co/api/v2/pokemon/737/',
#  'vikavolt': 'https://pokeapi.co/api/v2/pokemon/738/',
#  'crabrawler': 'https://pokeapi.co/api/v2/pokemon/739/',
#  'crabominable': 'https://pokeapi.co/api/v2/pokemon/740/',
#  'oricorio-baile': 'https://pokeapi.co/api/v2/pokemon/741/',
#  'cutiefly': 'https://pokeapi.co/api/v2/pokemon/742/',
#  'ribombee': 'https://pokeapi.co/api/v2/pokemon/743/',
#  'rockruff': 'https://pokeapi.co/api/v2/pokemon/744/',
#  'lycanroc-midday': 'https://pokeapi.co/api/v2/pokemon/745/',
#  'wishiwashi-solo': 'https://pokeapi.co/api/v2/pokemon/746/',
#  'mareanie': 'https://pokeapi.co/api/v2/pokemon/747/',
#  'toxapex': 'https://pokeapi.co/api/v2/pokemon/748/',
#  'mudbray': 'https://pokeapi.co/api/v2/pokemon/749/',
#  'mudsdale': 'https://pokeapi.co/api/v2/pokemon/750/',
#  'dewpider': 'https://pokeapi.co/api/v2/pokemon/751/',
#  'araquanid': 'https://pokeapi.co/api/v2/pokemon/752/',
#  'fomantis': 'https://pokeapi.co/api/v2/pokemon/753/',
#  'lurantis': 'https://pokeapi.co/api/v2/pokemon/754/',
#  'morelull': 'https://pokeapi.co/api/v2/pokemon/755/',
#  'shiinotic': 'https://pokeapi.co/api/v2/pokemon/756/',
#  'salandit': 'https://pokeapi.co/api/v2/pokemon/757/',
#  'salazzle': 'https://pokeapi.co/api/v2/pokemon/758/',
#  'stufful': 'https://pokeapi.co/api/v2/pokemon/759/',
#  'bewear': 'https://pokeapi.co/api/v2/pokemon/760/',
#  'bounsweet': 'https://pokeapi.co/api/v2/pokemon/761/',
#  'steenee': 'https://pokeapi.co/api/v2/pokemon/762/',
#  'tsareena': 'https://pokeapi.co/api/v2/pokemon/763/',
#  'comfey': 'https://pokeapi.co/api/v2/pokemon/764/',
#  'oranguru': 'https://pokeapi.co/api/v2/pokemon/765/',
#  'passimian': 'https://pokeapi.co/api/v2/pokemon/766/',
#  'wimpod': 'https://pokeapi.co/api/v2/pokemon/767/',
#  'golisopod': 'https://pokeapi.co/api/v2/pokemon/768/',
#  'sandygast': 'https://pokeapi.co/api/v2/pokemon/769/',
#  'palossand': 'https://pokeapi.co/api/v2/pokemon/770/',
#  'pyukumuku': 'https://pokeapi.co/api/v2/pokemon/771/',
#  'type-null': 'https://pokeapi.co/api/v2/pokemon/772/',
#  'silvally': 'https://pokeapi.co/api/v2/pokemon/773/',
#  'minior-red-meteor': 'https://pokeapi.co/api/v2/pokemon/774/',
#  'komala': 'https://pokeapi.co/api/v2/pokemon/775/',
#  'turtonator': 'https://pokeapi.co/api/v2/pokemon/776/',
#  'togedemaru': 'https://pokeapi.co/api/v2/pokemon/777/',
#  'mimikyu-disguised': 'https://pokeapi.co/api/v2/pokemon/778/',
#  'bruxish': 'https://pokeapi.co/api/v2/pokemon/779/',
#  'drampa': 'https://pokeapi.co/api/v2/pokemon/780/',
#  'dhelmise': 'https://pokeapi.co/api/v2/pokemon/781/',
#  'jangmo-o': 'https://pokeapi.co/api/v2/pokemon/782/',
#  'hakamo-o': 'https://pokeapi.co/api/v2/pokemon/783/',
#  'kommo-o': 'https://pokeapi.co/api/v2/pokemon/784/',
#  'tapu-koko': 'https://pokeapi.co/api/v2/pokemon/785/',
#  'tapu-lele': 'https://pokeapi.co/api/v2/pokemon/786/',
#  'tapu-bulu': 'https://pokeapi.co/api/v2/pokemon/787/',
#  'tapu-fini': 'https://pokeapi.co/api/v2/pokemon/788/',
#  'cosmog': 'https://pokeapi.co/api/v2/pokemon/789/',
#  'cosmoem': 'https://pokeapi.co/api/v2/pokemon/790/',
#  'solgaleo': 'https://pokeapi.co/api/v2/pokemon/791/',
#  'lunala': 'https://pokeapi.co/api/v2/pokemon/792/',
#  'nihilego': 'https://pokeapi.co/api/v2/pokemon/793/',
#  'buzzwole': 'https://pokeapi.co/api/v2/pokemon/794/',
#  'pheromosa': 'https://pokeapi.co/api/v2/pokemon/795/',
#  'xurkitree': 'https://pokeapi.co/api/v2/pokemon/796/',
#  'celesteela': 'https://pokeapi.co/api/v2/pokemon/797/',
#  'kartana': 'https://pokeapi.co/api/v2/pokemon/798/',
#  'guzzlord': 'https://pokeapi.co/api/v2/pokemon/799/',
#  'necrozma': 'https://pokeapi.co/api/v2/pokemon/800/',
#  'magearna': 'https://pokeapi.co/api/v2/pokemon/801/',
#  'marshadow': 'https://pokeapi.co/api/v2/pokemon/802/',
#  'poipole': 'https://pokeapi.co/api/v2/pokemon/803/',
#  'naganadel': 'https://pokeapi.co/api/v2/pokemon/804/',
#  'stakataka': 'https://pokeapi.co/api/v2/pokemon/805/',
#  'blacephalon': 'https://pokeapi.co/api/v2/pokemon/806/',
#  'zeraora': 'https://pokeapi.co/api/v2/pokemon/807/',
#  'meltan': 'https://pokeapi.co/api/v2/pokemon/808/',
#  'melmetal': 'https://pokeapi.co/api/v2/pokemon/809/',
#  'grookey': 'https://pokeapi.co/api/v2/pokemon/810/',
#  'thwackey': 'https://pokeapi.co/api/v2/pokemon/811/',
#  'rillaboom': 'https://pokeapi.co/api/v2/pokemon/812/',
#  'scorbunny': 'https://pokeapi.co/api/v2/pokemon/813/',
#  'raboot': 'https://pokeapi.co/api/v2/pokemon/814/',
#  'cinderace': 'https://pokeapi.co/api/v2/pokemon/815/',
#  'sobble': 'https://pokeapi.co/api/v2/pokemon/816/',
#  'drizzile': 'https://pokeapi.co/api/v2/pokemon/817/',
#  'inteleon': 'https://pokeapi.co/api/v2/pokemon/818/',
#  'skwovet': 'https://pokeapi.co/api/v2/pokemon/819/',
#  'greedent': 'https://pokeapi.co/api/v2/pokemon/820/',
#  'rookidee': 'https://pokeapi.co/api/v2/pokemon/821/',
#  'corvisquire': 'https://pokeapi.co/api/v2/pokemon/822/',
#  'corviknight': 'https://pokeapi.co/api/v2/pokemon/823/',
#  'blipbug': 'https://pokeapi.co/api/v2/pokemon/824/',
#  'dottler': 'https://pokeapi.co/api/v2/pokemon/825/',
#  'orbeetle': 'https://pokeapi.co/api/v2/pokemon/826/',
#  'nickit': 'https://pokeapi.co/api/v2/pokemon/827/',
#  'thievul': 'https://pokeapi.co/api/v2/pokemon/828/',
#  'gossifleur': 'https://pokeapi.co/api/v2/pokemon/829/',
#  'eldegoss': 'https://pokeapi.co/api/v2/pokemon/830/',
#  'wooloo': 'https://pokeapi.co/api/v2/pokemon/831/',
#  'dubwool': 'https://pokeapi.co/api/v2/pokemon/832/',
#  'chewtle': 'https://pokeapi.co/api/v2/pokemon/833/',
#  'drednaw': 'https://pokeapi.co/api/v2/pokemon/834/',
#  'yamper': 'https://pokeapi.co/api/v2/pokemon/835/',
#  'boltund': 'https://pokeapi.co/api/v2/pokemon/836/',
#  'rolycoly': 'https://pokeapi.co/api/v2/pokemon/837/',
#  'carkol': 'https://pokeapi.co/api/v2/pokemon/838/',
#  'coalossal': 'https://pokeapi.co/api/v2/pokemon/839/',
#  'applin': 'https://pokeapi.co/api/v2/pokemon/840/',
#  'flapple': 'https://pokeapi.co/api/v2/pokemon/841/',
#  'appletun': 'https://pokeapi.co/api/v2/pokemon/842/',
#  'silicobra': 'https://pokeapi.co/api/v2/pokemon/843/',
#  'sandaconda': 'https://pokeapi.co/api/v2/pokemon/844/',
#  'cramorant': 'https://pokeapi.co/api/v2/pokemon/845/',
#  'arrokuda': 'https://pokeapi.co/api/v2/pokemon/846/',
#  'barraskewda': 'https://pokeapi.co/api/v2/pokemon/847/',
#  'toxel': 'https://pokeapi.co/api/v2/pokemon/848/',
#  'toxtricity-amped': 'https://pokeapi.co/api/v2/pokemon/849/',
#  'sizzlipede': 'https://pokeapi.co/api/v2/pokemon/850/',
#  'centiskorch': 'https://pokeapi.co/api/v2/pokemon/851/',
#  'clobbopus': 'https://pokeapi.co/api/v2/pokemon/852/',
#  'grapploct': 'https://pokeapi.co/api/v2/pokemon/853/',
#  'sinistea': 'https://pokeapi.co/api/v2/pokemon/854/',
#  'polteageist': 'https://pokeapi.co/api/v2/pokemon/855/',
#  'hatenna': 'https://pokeapi.co/api/v2/pokemon/856/',
#  'hattrem': 'https://pokeapi.co/api/v2/pokemon/857/',
#  'hatterene': 'https://pokeapi.co/api/v2/pokemon/858/',
#  'impidimp': 'https://pokeapi.co/api/v2/pokemon/859/',
#  'morgrem': 'https://pokeapi.co/api/v2/pokemon/860/',
#  'grimmsnarl': 'https://pokeapi.co/api/v2/pokemon/861/',
#  'obstagoon': 'https://pokeapi.co/api/v2/pokemon/862/',
#  'perrserker': 'https://pokeapi.co/api/v2/pokemon/863/',
#  'cursola': 'https://pokeapi.co/api/v2/pokemon/864/',
#  'sirfetchd': 'https://pokeapi.co/api/v2/pokemon/865/',
#  'mr-rime': 'https://pokeapi.co/api/v2/pokemon/866/',
#  'runerigus': 'https://pokeapi.co/api/v2/pokemon/867/',
#  'milcery': 'https://pokeapi.co/api/v2/pokemon/868/',
#  'alcremie': 'https://pokeapi.co/api/v2/pokemon/869/',
#  'falinks': 'https://pokeapi.co/api/v2/pokemon/870/',
#  'pincurchin': 'https://pokeapi.co/api/v2/pokemon/871/',
#  'snom': 'https://pokeapi.co/api/v2/pokemon/872/',
#  'frosmoth': 'https://pokeapi.co/api/v2/pokemon/873/',
#  'stonjourner': 'https://pokeapi.co/api/v2/pokemon/874/',
#  'eiscue-ice': 'https://pokeapi.co/api/v2/pokemon/875/',
#  'indeedee-male': 'https://pokeapi.co/api/v2/pokemon/876/',
#  'morpeko': 'https://pokeapi.co/api/v2/pokemon/877/',
#  'cufant': 'https://pokeapi.co/api/v2/pokemon/878/',
#  'copperajah': 'https://pokeapi.co/api/v2/pokemon/879/',
#  'dracozolt': 'https://pokeapi.co/api/v2/pokemon/880/',
#  'arctozolt': 'https://pokeapi.co/api/v2/pokemon/881/',
#  'dracovish': 'https://pokeapi.co/api/v2/pokemon/882/',
#  'arctovish': 'https://pokeapi.co/api/v2/pokemon/883/',
#  'duraludon': 'https://pokeapi.co/api/v2/pokemon/884/',
#  'dreepy': 'https://pokeapi.co/api/v2/pokemon/885/',
#  'drakloak': 'https://pokeapi.co/api/v2/pokemon/886/',
#  'dragapult': 'https://pokeapi.co/api/v2/pokemon/887/',
#  'zacian-hero': 'https://pokeapi.co/api/v2/pokemon/888/',
#  'zamazenta-hero': 'https://pokeapi.co/api/v2/pokemon/889/',
#  'eternatus': 'https://pokeapi.co/api/v2/pokemon/890/',
#  'kubfu': 'https://pokeapi.co/api/v2/pokemon/891/',
#  'urshifu-single-strike': 'https://pokeapi.co/api/v2/pokemon/892/',
#  'zarude': 'https://pokeapi.co/api/v2/pokemon/893/',
#  'regieleki': 'https://pokeapi.co/api/v2/pokemon/894/',
#  'regidrago': 'https://pokeapi.co/api/v2/pokemon/895/',
#  'glastrier': 'https://pokeapi.co/api/v2/pokemon/896/',
#  'spectrier': 'https://pokeapi.co/api/v2/pokemon/897/',
#  'calyrex': 'https://pokeapi.co/api/v2/pokemon/898/',
#  'deoxys-attack': 'https://pokeapi.co/api/v2/pokemon/10001/',
#  'deoxys-defense': 'https://pokeapi.co/api/v2/pokemon/10002/',
#  'deoxys-speed': 'https://pokeapi.co/api/v2/pokemon/10003/',
#  'wormadam-sandy': 'https://pokeapi.co/api/v2/pokemon/10004/',
#  'wormadam-trash': 'https://pokeapi.co/api/v2/pokemon/10005/',
#  'shaymin-sky': 'https://pokeapi.co/api/v2/pokemon/10006/',
#  'giratina-origin': 'https://pokeapi.co/api/v2/pokemon/10007/',
#  'rotom-heat': 'https://pokeapi.co/api/v2/pokemon/10008/',
#  'rotom-wash': 'https://pokeapi.co/api/v2/pokemon/10009/',
#  'rotom-frost': 'https://pokeapi.co/api/v2/pokemon/10010/',
#  'rotom-fan': 'https://pokeapi.co/api/v2/pokemon/10011/',
#  'rotom-mow': 'https://pokeapi.co/api/v2/pokemon/10012/',
#  'castform-sunny': 'https://pokeapi.co/api/v2/pokemon/10013/',
#  'castform-rainy': 'https://pokeapi.co/api/v2/pokemon/10014/',
#  'castform-snowy': 'https://pokeapi.co/api/v2/pokemon/10015/',
#  'basculin-blue-striped': 'https://pokeapi.co/api/v2/pokemon/10016/',
#  'darmanitan-zen': 'https://pokeapi.co/api/v2/pokemon/10017/',
#  'meloetta-pirouette': 'https://pokeapi.co/api/v2/pokemon/10018/',
#  'tornadus-therian': 'https://pokeapi.co/api/v2/pokemon/10019/',
#  'thundurus-therian': 'https://pokeapi.co/api/v2/pokemon/10020/',
#  'landorus-therian': 'https://pokeapi.co/api/v2/pokemon/10021/',
#  'kyurem-black': 'https://pokeapi.co/api/v2/pokemon/10022/',
#  'kyurem-white': 'https://pokeapi.co/api/v2/pokemon/10023/',
#  'keldeo-resolute': 'https://pokeapi.co/api/v2/pokemon/10024/',
#  'meowstic-female': 'https://pokeapi.co/api/v2/pokemon/10025/',
#  'aegislash-blade': 'https://pokeapi.co/api/v2/pokemon/10026/',
#  'pumpkaboo-small': 'https://pokeapi.co/api/v2/pokemon/10027/',
#  'pumpkaboo-large': 'https://pokeapi.co/api/v2/pokemon/10028/',
#  'pumpkaboo-super': 'https://pokeapi.co/api/v2/pokemon/10029/',
#  'gourgeist-small': 'https://pokeapi.co/api/v2/pokemon/10030/',
#  'gourgeist-large': 'https://pokeapi.co/api/v2/pokemon/10031/',
#  'gourgeist-super': 'https://pokeapi.co/api/v2/pokemon/10032/',
#  'venusaur-mega': 'https://pokeapi.co/api/v2/pokemon/10033/',
#  'charizard-mega-x': 'https://pokeapi.co/api/v2/pokemon/10034/',
#  'charizard-mega-y': 'https://pokeapi.co/api/v2/pokemon/10035/',
#  'blastoise-mega': 'https://pokeapi.co/api/v2/pokemon/10036/',
#  'alakazam-mega': 'https://pokeapi.co/api/v2/pokemon/10037/',
#  'gengar-mega': 'https://pokeapi.co/api/v2/pokemon/10038/',
#  'kangaskhan-mega': 'https://pokeapi.co/api/v2/pokemon/10039/',
#  'pinsir-mega': 'https://pokeapi.co/api/v2/pokemon/10040/',
#  'gyarados-mega': 'https://pokeapi.co/api/v2/pokemon/10041/',
#  'aerodactyl-mega': 'https://pokeapi.co/api/v2/pokemon/10042/',
#  'mewtwo-mega-x': 'https://pokeapi.co/api/v2/pokemon/10043/',
#  'mewtwo-mega-y': 'https://pokeapi.co/api/v2/pokemon/10044/',
#  'ampharos-mega': 'https://pokeapi.co/api/v2/pokemon/10045/',
#  'scizor-mega': 'https://pokeapi.co/api/v2/pokemon/10046/',
#  'heracross-mega': 'https://pokeapi.co/api/v2/pokemon/10047/',
#  'houndoom-mega': 'https://pokeapi.co/api/v2/pokemon/10048/',
#  'tyranitar-mega': 'https://pokeapi.co/api/v2/pokemon/10049/',
#  'blaziken-mega': 'https://pokeapi.co/api/v2/pokemon/10050/',
#  'gardevoir-mega': 'https://pokeapi.co/api/v2/pokemon/10051/',
#  'mawile-mega': 'https://pokeapi.co/api/v2/pokemon/10052/',
#  'aggron-mega': 'https://pokeapi.co/api/v2/pokemon/10053/',
#  'medicham-mega': 'https://pokeapi.co/api/v2/pokemon/10054/',
#  'manectric-mega': 'https://pokeapi.co/api/v2/pokemon/10055/',
#  'banette-mega': 'https://pokeapi.co/api/v2/pokemon/10056/',
#  'absol-mega': 'https://pokeapi.co/api/v2/pokemon/10057/',
#  'garchomp-mega': 'https://pokeapi.co/api/v2/pokemon/10058/',
#  'lucario-mega': 'https://pokeapi.co/api/v2/pokemon/10059/',
#  'abomasnow-mega': 'https://pokeapi.co/api/v2/pokemon/10060/',
#  'floette-eternal': 'https://pokeapi.co/api/v2/pokemon/10061/',
#  'latias-mega': 'https://pokeapi.co/api/v2/pokemon/10062/',
#  'latios-mega': 'https://pokeapi.co/api/v2/pokemon/10063/',
#  'swampert-mega': 'https://pokeapi.co/api/v2/pokemon/10064/',
#  'sceptile-mega': 'https://pokeapi.co/api/v2/pokemon/10065/',
#  'sableye-mega': 'https://pokeapi.co/api/v2/pokemon/10066/',
#  'altaria-mega': 'https://pokeapi.co/api/v2/pokemon/10067/',
#  'gallade-mega': 'https://pokeapi.co/api/v2/pokemon/10068/',
#  'audino-mega': 'https://pokeapi.co/api/v2/pokemon/10069/',
#  'sharpedo-mega': 'https://pokeapi.co/api/v2/pokemon/10070/',
#  'slowbro-mega': 'https://pokeapi.co/api/v2/pokemon/10071/',
#  'steelix-mega': 'https://pokeapi.co/api/v2/pokemon/10072/',
#  'pidgeot-mega': 'https://pokeapi.co/api/v2/pokemon/10073/',
#  'glalie-mega': 'https://pokeapi.co/api/v2/pokemon/10074/',
#  'diancie-mega': 'https://pokeapi.co/api/v2/pokemon/10075/',
#  'metagross-mega': 'https://pokeapi.co/api/v2/pokemon/10076/',
#  'kyogre-primal': 'https://pokeapi.co/api/v2/pokemon/10077/',
#  'groudon-primal': 'https://pokeapi.co/api/v2/pokemon/10078/',
#  'rayquaza-mega': 'https://pokeapi.co/api/v2/pokemon/10079/',
#  'pikachu-rock-star': 'https://pokeapi.co/api/v2/pokemon/10080/',
#  'pikachu-belle': 'https://pokeapi.co/api/v2/pokemon/10081/',
#  'pikachu-pop-star': 'https://pokeapi.co/api/v2/pokemon/10082/',
#  'pikachu-phd': 'https://pokeapi.co/api/v2/pokemon/10083/',
#  'pikachu-libre': 'https://pokeapi.co/api/v2/pokemon/10084/',
#  'pikachu-cosplay': 'https://pokeapi.co/api/v2/pokemon/10085/',
#  'hoopa-unbound': 'https://pokeapi.co/api/v2/pokemon/10086/',
#  'camerupt-mega': 'https://pokeapi.co/api/v2/pokemon/10087/',
#  'lopunny-mega': 'https://pokeapi.co/api/v2/pokemon/10088/',
#  'salamence-mega': 'https://pokeapi.co/api/v2/pokemon/10089/',
#  'beedrill-mega': 'https://pokeapi.co/api/v2/pokemon/10090/',
#  'rattata-alola': 'https://pokeapi.co/api/v2/pokemon/10091/',
#  'raticate-alola': 'https://pokeapi.co/api/v2/pokemon/10092/',
#  'raticate-totem-alola': 'https://pokeapi.co/api/v2/pokemon/10093/',
#  'pikachu-original-cap': 'https://pokeapi.co/api/v2/pokemon/10094/',
#  'pikachu-hoenn-cap': 'https://pokeapi.co/api/v2/pokemon/10095/',
#  'pikachu-sinnoh-cap': 'https://pokeapi.co/api/v2/pokemon/10096/',
#  'pikachu-unova-cap': 'https://pokeapi.co/api/v2/pokemon/10097/',
#  'pikachu-kalos-cap': 'https://pokeapi.co/api/v2/pokemon/10098/',
#  'pikachu-alola-cap': 'https://pokeapi.co/api/v2/pokemon/10099/',
#  'raichu-alola': 'https://pokeapi.co/api/v2/pokemon/10100/',
#  'sandshrew-alola': 'https://pokeapi.co/api/v2/pokemon/10101/',
#  'sandslash-alola': 'https://pokeapi.co/api/v2/pokemon/10102/',
#  ...}

# %% [markdown]
# ## Ok, let's try a more complicated API - for stocks!
# ![](assets/alpha-vantage.png)
# If you haven't already - grab your free API key for Alpha Vantage [here](https://www.alphavantage.co). It takes five seconds.
#
# **(THREAD): Why do you think companies would require the use of an API key?**
#
# Alpha Vantage has documentation [here](https://www.alphavantage.co/documentation/).

# %%
# Most APIs have a single base URL from which API calls are made.
# If you look closely at the examples, this is Alpha Vantage's.

intraday_function = 'TIME_SERIES_INTRADAY'

base_url = "https://www.alphavantage.co/"
query_endpoint = "query"
api_key = "YOUR_KEY"

# %%
# Let's build out this request.
# This is a very common format for pure API requests to come in
params = {
    'function': intraday_function,
    'symbol': 'IBM',
    'interval': '5min',
    'apikey': 'demo'
}

# Let's grab that data!
r = requests.get(base_url + query_endpoint, params=params)

# %%
ibm = r.json()
ibm['Meta Data']
# Out:
# {'1. Information': 'Intraday (5min) open, high, low, close prices and volume',
#  '2. Symbol': 'IBM',
#  '3. Last Refreshed': '2021-02-12 19:50:00',
#  '4. Interval': '5min',
#  '5. Output Size': 'Compact',
#  '6. Time Zone': 'US/Eastern'}

# %% [markdown]
# ### Challenge
# Write your own function that inputs a ticker symbol and outputs the above.

# %%
def get_intraday(stock_symbol, apikey='demo'):
    params = {
        'function': intraday_function,
        'symbol': stock_symbol,
        'interval': '5min',
        'apikey': apikey
    }

    # Let's grab that data!
    r = requests.get(base_url + query_endpoint, params=params)
    
    return r.json()

ibm = get_intraday('IBM', apikey='demo')
ibm['Meta Data']
# Out:
# {'1. Information': 'Intraday (5min) open, high, low, close prices and volume',
#  '2. Symbol': 'IBM',
#  '3. Last Refreshed': '2021-02-12 19:50:00',
#  '4. Interval': '5min',
#  '5. Output Size': 'Compact',
#  '6. Time Zone': 'US/Eastern'}

# %% [markdown]
# ### Did this feel like a lot of work? You're not alone.
# For web APIs such as these, open sourcerers (ordinary programmers like you and me!) like to build language-specific **API wrappers** to easier call the API. Interestingly, based on our very vague definition of APIs, API wrappers are also themselves APIs!
#
# Alpha Vantage has a Python API wrapper made by user `RomelTorres` [here](https://github.com/RomelTorres/alpha_vantage)!
#
# ![](assets/opensource.jpg)

# %% [markdown]
# ## You want data? You got data.
#
# ### Key Takeaway #1: Your favorite thing has a free API
# * **Stock prices**: [Alpha Vantage](https://github.com/RomelTorres/alpha_vantage)
# * **Cryptocurrency prices**: [ccxt](https://github.com/ccxt/ccxt) provides a unified API for several cryptocurrency markets. You can even buy and sell crypto from within Python!
# * **Weather**: [OpenWeather](https://openweathermap.org/api)
#
# ### Key Takeaway #2: Your favorite website has a free API
# Below is a brief list of websites that have a free API. Note that "free" here means "zero-cost", not "permissive and easy to use." APIs can be abused. Not all Twitter bots are friendly like [Every Sheriff Bot](https://twitter.com/EverySheriff).
# * Twitter
# * Reddit
# * Yelp
# * Twitch
# * Facebook/Instagram
# * GitHub (yes, even GitHub!)
# * Most Google services
# * Spotify
# * Slack (no, you can't have a key.)

# %% [markdown]
# ## Part 4: Web Scraping with Beautiful Soup!
# ![](https://static.datasciencedojo.com/wp-content/uploads/PythonBeautifulSoup-04-495x400.png)
#
# The library `bs4` (Beautiful Soup) allows you to take the raw HTML from a `request` and pick out the parts you need!

# %%
from bs4 import BeautifulSoup

# %%
url = "https://example.com"
req = requests.get(url)
soup = BeautifulSoup(req.text)  # Convert to a BeautifulSoup object

# %%
soup
# Out:
# <!DOCTYPE html>
# <html>
# <head>
# <title>Example Domain</title>
# <meta charset="utf-8"/>
# <meta content="text/html; charset=utf-8" http-equiv="Content-type"/>
# <meta content="width=device-width, initial-scale=1" name="viewport"/>
# <style type="text/css">
#     body {
#         background-color: #f0f0f2;
#         margin: 0;
#         padding: 0;
#         font-family: -apple-system, system-ui, BlinkMacSystemFont, "Segoe UI", "Open Sans", "Helvetica Neue", Helvetica, Arial, sans-serif;
#
#     }
#     div {
#         width: 600px;
#         margin: 5em auto;
#         padding: 2em;
#         background-color: #fdfdff;
#         border-radius: 0.5em;
#         box-shadow: 2px 3px 7px 2px rgba(0,0,0,0.02);
#     }
#     a:link, a:visited {
#         color: #38488f;
#         text-decoration: none;
#     }
#     @media (max-width: 700px) {
#         div {
#             margin: 0 auto;
#             width: auto;
#         }
#     }
#     </style>
# </head>
# <body>
# <div>
# <h1>Example Domain</h1>
# <p>This domain is for use in illustrative examples in documents. You may use this
#     domain in literature without prior coordination or asking for permission.</p>
# <p><a href="https://www.iana.org/domains/example">More information...</a></p>
# </div>
# </body>
# </html>

# %%
# Get a list of all h1 tags
h1_tags = soup.select('h1')
h1_tags
# Out:
# [<h1>Example Domain</h1>]

# %%
# Get the text part of the first h1 tag
h1_tags[0].text
# Out:
# 'Example Domain'

# %%
# Challenge: Can you print the text of all <p> tags?

for ptag in soup.select('p'):
    print(ptag.text)
# Out:
# This domain is for use in illustrative examples in documents. You may use this
#     domain in literature without prior coordination or asking for permission.
# More information...

# %% [markdown]
# ### Let's use BeautifulSoup to actually scrape a website!
# Let's scrape: [Real Python](https://realpython.com), a new (very good) blog site for Python users (aimed at mostly beginners).

# %%
url = "https://realpython.com"
req = requests.get(url)

# %%
req.status_code
# Out:
# 200

# %%
soup = BeautifulSoup(req.text)

# %%
# Let's scrape a list of articles from the front page!
h2s = soup.select('h2.card-title')
h2s
# Out:
# [<h2 class="card-title h2 my-0 py-0">Creating PyQt Layouts for GUI Applications</h2>,
#  <h2 class="card-title h4 my-0 py-0">Pandas Sort: Your Guide to Sorting Data in Python</h2>,
#  <h2 class="card-title h4 my-0 py-0">Python Microservices With gRPC</h2>,
#  <h2 class="card-title h4 my-0 py-0">Python Modulo: Using the % Operator</h2>,
#  <h2 class="card-title h4 my-0 py-0">Python Inner Functions: What Are They Good For?</h2>,
#  <h2 class="card-title h4 my-0 py-0">Qt Designer and Python: Build Your GUI Applications Faster</h2>,
#  <h2 class="card-title h4 my-0 py-0">Plot With Pandas: Python Data Visualization Basics</h2>,
#  <h2 class="card-title h4 my-0 py-0">Python Web Applications: Deploy Your Script as a Flask App</h2>,
#  <h2 class="card-title h4 my-0 py-0">Stochastic Gradient Descent Algorithm With Python and NumPy</h2>,
#  <h2 class="card-title h4 my-0 py-0">Evaluate Expressions Dynamically With Python eval()</h2>,
#  <h2 class="card-title h4 my-0 py-0">How to Use Python: Your First Steps</h2>,
#  <h2 class="card-title h4 my-0 py-0">C for Python Programmers</h2>,
#  <h2 class="card-title h4 my-0 py-0">Introduction to Sorting Algorithms in Python</h2>]

# %%
titles = [h2.get_text() for h2 in h2s]
titles
# Out:
# ['Creating PyQt Layouts for GUI Applications',
#  'Pandas Sort: Your Guide to Sorting Data in Python',
#  'Python Microservices With gRPC',
#  'Python Modulo: Using the % Operator',
#  'Python Inner Functions: What Are They Good For?',
#  'Qt Designer and Python: Build Your GUI Applications Faster',
#  'Plot With Pandas: Python Data Visualization Basics',
#  'Python Web Applications: Deploy Your Script as a Flask App',
#  'Stochastic Gradient Descent Algorithm With Python and NumPy',
#  'Evaluate Expressions Dynamically With Python eval()',
#  'How to Use Python: Your First Steps',
#  'C for Python Programmers',
#  'Introduction to Sorting Algorithms in Python']

# %%
link = h2s[5].find_parent()
link
# Out:
# <a href="/qt-designer-python/">
# <h2 class="card-title h4 my-0 py-0">Qt Designer and Python: Build Your GUI Applications Faster</h2>
# </a>

# %%
link.attrs['href']
# Out:
# '/qt-designer-python/'

# %%
links = ["https://realpython.com" + h2.find_parent().attrs['href'] for h2 in h2s]
links
# Out:
# ['https://realpython.com/courses/creating-pyqt-layouts-gui-applications/',
#  'https://realpython.com/pandas-sort-python/',
#  'https://realpython.com/python-microservices-grpc/',
#  'https://realpython.com/courses/python-modulo-operator/',
#  'https://realpython.com/inner-functions-what-are-they-good-for/',
#  'https://realpython.com/qt-designer-python/',
#  'https://realpython.com/courses/plot-pandas-data-visualization/',
#  'https://realpython.com/python-web-applications/',
#  'https://realpython.com/gradient-descent-algorithm-python/',
#  'https://realpython.com/courses/evaluate-expressions-dynamically-python-eval/',
#  'https://realpython.com/python-first-steps/',
#  'https://realpython.com/c-for-python-programmers/',
#  'https://realpython.com/courses/intro-sorting-algorithms/']

# %%
article_req = requests.get(links[5])
article_soup = BeautifulSoup(article_req.text)
article_soup.select('p')[1].get_text()
# Out:
# '\nby Leodanis Pozo Ramos\n Feb 03, 2021\n\n\ngui\nintermediate\n\n\n\nTweet\nShare\nEmail\n\n\n\n'

# %%
def get_article_contents(link):
    article_req = requests.get(link)
    article_soup = BeautifulSoup(article_req.text)
    try:
        return article_soup.select('p')[2].get_text()
    except:
        return ""

# %%
contents = [get_article_contents(link) for link in links[:5]]
contents
# Out:
# ['In this course, you’ll learn:',
#  'Table of Contents',
#  'Table of Contents',
#  'In this course, you’ll learn:',
#  'Table of Contents']

# %% [markdown]
# ## Conclusion & Summary
# Today, we:
# * Learned how HTTP works
# * Made HTTP requests from Python
# * Read API documentation and got the data we want
# * Scraped a website using BeautifulSoup
